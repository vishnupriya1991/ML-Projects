# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#read the file
df=pd.read_csv("Victims_of_rape.csv")
df
# Out:
#                       Area_Name  Year                Subgroup  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# ...                         ...   ...                     ...
# 1045                West Bengal  2009  Victims of Incest Rape
# 1046                West Bengal  2009   Victims of Other Rape
# 1047                West Bengal  2010      Total Rape Victims
# 1048                West Bengal  2010  Victims of Incest Rape
# 1049                West Bengal  2010   Victims of Other Rape
#
#       Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                       3                     0                          0
# ...

# %%
df.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
#check the number of rows and columns 
df.shape
# Out:
# (1050, 11)

# %%
#data types of the set
df.dtypes
# Out:
# Area_Name                    object
# Year                          int64
# Subgroup                     object
# Rape_Cases_Reported           int64
# Victims_Above_50_Yrs          int64
# Victims_Between_10-14_Yrs     int64
# Victims_Between_14-18_Yrs     int64
# Victims_Between_18-30_Yrs     int64
# Victims_Between_30-50_Yrs     int64
# Victims_of_Rape_Total         int64
# Victims_Upto_10_Yrs           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Area_Name                  1050 non-null   object
#  1   Year                       1050 non-null   int64
#  2   Subgroup                   1050 non-null   object
#  3   Rape_Cases_Reported        1050 non-null   int64
#  4   Victims_Above_50_Yrs       1050 non-null   int64
#  5   Victims_Between_10-14_Yrs  1050 non-null   int64
#  6   Victims_Between_14-18_Yrs  1050 non-null   int64
#  7   Victims_Between_18-30_Yrs  1050 non-null   int64
#  8   Victims_Between_30-50_Yrs  1050 non-null   int64
#  9   Victims_of_Rape_Total      1050 non-null   int64
#  10  Victims_Upto_10_Yrs        1050 non-null   int64
# dtypes: int64(9), object(2)
# memory usage: 90.4+ KB

# %%
#check the missing values using heatmap
sns.heatmap(df.isnull())

# %%
df.isnull().sum()
#no null data found
# Out:
# Area_Name                    0
# Year                         0
# Subgroup                     0
# Rape_Cases_Reported          0
# Victims_Above_50_Yrs         0
# Victims_Between_10-14_Yrs    0
# Victims_Between_14-18_Yrs    0
# Victims_Between_18-30_Yrs    0
# Victims_Between_30-50_Yrs    0
# Victims_of_Rape_Total        0
# Victims_Upto_10_Yrs          0
# dtype: int64

# %%
df.columns
#the columns in the dataset
# Out:
# Index(['Area_Name', 'Year', 'Subgroup', 'Rape_Cases_Reported',
#        'Victims_Above_50_Yrs', 'Victims_Between_10-14_Yrs',
#        'Victims_Between_14-18_Yrs', 'Victims_Between_18-30_Yrs',
#        'Victims_Between_30-50_Yrs', 'Victims_of_Rape_Total',
#        'Victims_Upto_10_Yrs'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis

# %%
#checking the unique values and then the count is taken

for i in df.columns:
    print(df[i].value_counts())
    print()
# Out:
# Uttar Pradesh                30
# Gujarat                      30
# Madhya Pradesh               30
# Sikkim                       30
# Delhi                        30
# Bihar                        30
# Karnataka                    30
# Maharashtra                  30
# Arunachal Pradesh            30
# Kerala                       30
# Meghalaya                    30
# Assam                        30
# Punjab                       30
# Puducherry                   30
# Rajasthan                    30
# Tripura                      30
# Mizoram                      30
# Jammu & Kashmir              30
# Manipur                      30
# Chandigarh                   30
# Tamil Nadu                   30
# Lakshadweep                  30
# Chhattisgarh                 30
# Himachal Pradesh             30
# Daman & Diu                  30
# Goa                          30
# Andaman & Nicobar Islands    30
# Andhra Pradesh               30
# West Bengal                  30
# ...

# %% [markdown]
# Observation
#
# The dataset relates to the information of rape which is given state wise for the years starting from 2001 to 2010.
# Subgroup is further divided in to Victims of Incest Rape, Total Rape Victims and Victims of other Rape.
# Rape Cases Reported for each of the Subgroup mentioned above is listed.
# The above rape cases reported is further divided into Victims above 50 years, Victims between 10-14 years, Victims between 14-18 years, Victims between 18-30 years, Victims between 30-50 years, Victims upto 10 years and Victims of Rape in Total.

# %%
#check the distribution of the data
sns.distplot(df['Rape_Cases_Reported'])
#the data is skewed

# %%
sns.distplot(df['Victims_Above_50_Yrs'])

# %%
sns.distplot(df['Victims_Between_10-14_Yrs'])
#data is skewed

# %%
sns.distplot(df['Victims_Between_18-30_Yrs'])
#data is skewed

# %%
sns.boxplot(df['Victims_Between_18-30_Yrs'])
#there are outliers in the dataset

# %%
sns.boxplot(df['Victims_Between_10-14_Yrs'])
#there are outliers

# %%
sns.boxplot(df['Victims_Above_50_Yrs'])
#there are outliers

# %%
sns.boxplot(df['Victims_Upto_10_Yrs'])
#there are outliers

# %%
df.groupby(['Area_Name','Year','Subgroup']).mean()
# Out:
#                                                        Rape_Cases_Reported  \
# Area_Name                 Year Subgroup
# Andaman & Nicobar Islands 2001 Total Rape Victims                        3
#                                Victims of Incest Rape                    1
#                                Victims of Other Rape                     2
#                           2002 Total Rape Victims                        2
#                                Victims of Incest Rape                    0
# ...                                                                    ...
# West Bengal               2009 Victims of Incest Rape                    3
#                                Victims of Other Rape                  2333
#                           2010 Total Rape Victims                     2311
#                                Victims of Incest Rape                    4
#                                Victims of Other Rape                  2307
#
# ...

# %%
dfgrouped=df.groupby(['Area_Name','Year']).mean()
dfgrouped
# Out:
#                                 Rape_Cases_Reported  Victims_Above_50_Yrs  \
# Area_Name                 Year
# Andaman & Nicobar Islands 2001             2.000000              0.000000
#                           2002             1.333333              0.000000
#                           2003             1.333333              0.000000
#                           2004             6.666667              0.000000
#                           2005             2.666667              0.000000
# ...                                             ...                   ...
# West Bengal               2006          1154.000000              0.000000
#                           2007          1404.000000              3.333333
#                           2008          1508.666667              0.666667
#                           2009          1557.333333              0.000000
#                           2010          1540.666667              0.000000
#
# ...

# %% [markdown]
# Analysing Anadaman & Nicobar Islands

# %%
Andaman=df[(df['Area_Name']=='Andaman & Nicobar Islands')]
Andaman
# Out:
#                     Area_Name  Year                Subgroup  \
# 0   Andaman & Nicobar Islands  2001      Total Rape Victims
# 1   Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2   Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3   Andaman & Nicobar Islands  2002      Total Rape Victims
# 4   Andaman & Nicobar Islands  2002  Victims of Incest Rape
# 5   Andaman & Nicobar Islands  2002   Victims of Other Rape
# 6   Andaman & Nicobar Islands  2003      Total Rape Victims
# 7   Andaman & Nicobar Islands  2003  Victims of Incest Rape
# 8   Andaman & Nicobar Islands  2003   Victims of Other Rape
# 9   Andaman & Nicobar Islands  2004      Total Rape Victims
# 10  Andaman & Nicobar Islands  2004  Victims of Incest Rape
# 11  Andaman & Nicobar Islands  2004   Victims of Other Rape
# 12  Andaman & Nicobar Islands  2005      Total Rape Victims
# 13  Andaman & Nicobar Islands  2005  Victims of Incest Rape
# 14  Andaman & Nicobar Islands  2005   Victims of Other Rape
# ...

# %%
Andaman.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
andamangroup=Andaman.groupby(['Area_Name','Year','Subgroup']).mean()
andamangroup
# Out:
#                                                        Rape_Cases_Reported  \
# Area_Name                 Year Subgroup
# Andaman & Nicobar Islands 2001 Total Rape Victims                        3
#                                Victims of Incest Rape                    1
#                                Victims of Other Rape                     2
#                           2002 Total Rape Victims                        2
#                                Victims of Incest Rape                    0
#                                Victims of Other Rape                     2
#                           2003 Total Rape Victims                        2
#                                Victims of Incest Rape                    0
#                                Victims of Other Rape                     2
#                           2004 Total Rape Victims                       10
#                                Victims of Incest Rape                    0
# ...

# %%
andamangroup.head()
# Out:
#                                                        Rape_Cases_Reported  \
# Area_Name                 Year Subgroup
# Andaman & Nicobar Islands 2001 Total Rape Victims                        3
#                                Victims of Incest Rape                    1
#                                Victims of Other Rape                     2
#                           2002 Total Rape Victims                        2
#                                Victims of Incest Rape                    0
#
#                                                        Victims_Above_50_Yrs  \
# Area_Name                 Year Subgroup
# Andaman & Nicobar Islands 2001 Total Rape Victims                         0
#                                Victims of Incest Rape                     0
#                                Victims of Other Rape                      0
#                           2002 Total Rape Victims                         0
# ...

# %%
sns.countplot(x='Victims_Between_10-14_Yrs',data=Andaman)

# %%
sns.countplot(x='Victims_Upto_10_Yrs',data=Andaman)

# %%
#total number of victims above the age of 50
j=[]
for i in andamangroup['Victims_Above_50_Yrs']:
    j.append(i)
print(sum(j))

#there are no victims above 50 years
# Out:
# 0

# %%
#total number of victims between 10-14 years
j=[]
for i in andamangroup['Victims_Between_10-14_Yrs']:
    j.append(i)
print(sum(j))

#there are 16 victims between 10-14 years
# Out:
# 16

# %%
#total number of victims between 14-18 years
j=[]
for i in andamangroup['Victims_Between_14-18_Yrs']:
    j.append(i)
print(sum(j))

#there are 88 victims between 14-18 years
# Out:
# 88

# %%
andamangroup.sum(axis=0)
suma=pd.DataFrame(andamangroup.sum(axis=0))
suma.columns=['Andaman & Nicobar']
andamangroup.sum(axis=0)
#The highest no of rapes have taken to the children between 14 and 18 which shows they are very vulnerable in the region.
#They are followed by adults of 18-30 and kids of 10-14 and kids below 14 years.
#There has been no case reported for women above 50 years
# Out:
# Rape_Cases_Reported          168
# Victims_Above_50_Yrs           0
# Victims_Between_10-14_Yrs     16
# Victims_Between_14-18_Yrs     88
# Victims_Between_18-30_Yrs     42
# Victims_Between_30-50_Yrs      8
# Victims_of_Rape_Total        168
# Victims_Upto_10_Yrs           14
# dtype: int64

# %%
andamangroup.sum(axis=1)
# Out:
# Area_Name                  Year  Subgroup
# Andaman & Nicobar Islands  2001  Total Rape Victims         9
#                                  Victims of Incest Rape     3
#                                  Victims of Other Rape      6
#                            2002  Total Rape Victims         6
#                                  Victims of Incest Rape     0
#                                  Victims of Other Rape      6
#                            2003  Total Rape Victims         6
#                                  Victims of Incest Rape     0
#                                  Victims of Other Rape      6
#                            2004  Total Rape Victims        30
#                                  Victims of Incest Rape     0
#                                  Victims of Other Rape     30
#                            2005  Total Rape Victims        12
#                                  Victims of Incest Rape     0
# ...

# %% [markdown]
# Observation:
#
# Year wise there has been increase in the rape cases by 8 times from 9 reported in 2001 to 72 reported in 2010.
# Incest rape has been almost nil in Andaman & Nicobar since only 2001, 3 cases were reported which has become Nil in the following years.
# 2010 has reported highest rape cases with count being 72 followed by 2009, 54 and by 2008 and 2004 with 36 and 30 cases respectively.

# %% [markdown]
# Analysing Tripura

# %%
Tripura=df[(df['Area_Name']=='Tripura')]
Tripura
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 930   Tripura  2001      Total Rape Victims                  102
# 931   Tripura  2001  Victims of Incest Rape                    0
# 932   Tripura  2001   Victims of Other Rape                  102
# 933   Tripura  2002      Total Rape Victims                  108
# 934   Tripura  2002  Victims of Incest Rape                    0
# 935   Tripura  2002   Victims of Other Rape                  108
# 936   Tripura  2003      Total Rape Victims                  114
# 937   Tripura  2003  Victims of Incest Rape                    0
# 938   Tripura  2003   Victims of Other Rape                  114
# 939   Tripura  2004      Total Rape Victims                  160
# 940   Tripura  2004  Victims of Incest Rape                    1
# 941   Tripura  2004   Victims of Other Rape                  159
# 942   Tripura  2005      Total Rape Victims                  162
# ...

# %%
Tripura.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 930   Tripura  2001      Total Rape Victims                  102
# 931   Tripura  2001  Victims of Incest Rape                    0
# 932   Tripura  2001   Victims of Other Rape                  102
# 933   Tripura  2002      Total Rape Victims                  108
# 934   Tripura  2002  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 930                     0                          0
# 931                     0                          0
# 932                     0                          0
# 933                     0                          0
# 934                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 930                         50                         47
# 931                          0                          0
# 932                         50                         47
# ...

# %%
tripuragroup=Tripura.groupby(['Area_Name','Year','Subgroup']).mean()
tripuragroup
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Tripura   2001 Total Rape Victims                      102
#                Victims of Incest Rape                    0
#                Victims of Other Rape                   102
#           2002 Total Rape Victims                      108
#                Victims of Incest Rape                    0
#                Victims of Other Rape                   108
#           2003 Total Rape Victims                      114
#                Victims of Incest Rape                    0
#                Victims of Other Rape                   114
#           2004 Total Rape Victims                      160
#                Victims of Incest Rape                    1
#                Victims of Other Rape                   159
#           2005 Total Rape Victims                      162
#                Victims of Incest Rape                    0
# ...

# %%
sns.countplot(x='Rape_Cases_Reported',data=Tripura)

# %%
tripuragroup.sum(axis=0)
sumt=pd.DataFrame(tripuragroup.sum(axis=0))
sumt.columns=['Tripura']
tripuragroup.sum(axis=0)
#The total cases in Tripura for 10 years is 3248. The highest victims are under the age 18-30 - 2002 victims
#This is followed by 14-18 yrs - 590 victims and 220 nos between 10-14 yrs and 116 nos below 10 years
# Out:
# Rape_Cases_Reported          3248
# Victims_Above_50_Yrs            2
# Victims_Between_10-14_Yrs     220
# Victims_Between_14-18_Yrs     590
# Victims_Between_18-30_Yrs    2002
# Victims_Between_30-50_Yrs     322
# Victims_of_Rape_Total        3252
# Victims_Upto_10_Yrs           116
# dtype: int64

# %%
tripuragroup.sum(axis=1)
#Incest rape has been reported only in the years 2004 and 2006
#year by year cases has been increased by 2.33 times from 306 in 2001 to 714 in 2010.
# Out:
# Area_Name  Year  Subgroup
# Tripura    2001  Total Rape Victims        306
#                  Victims of Incest Rape      0
#                  Victims of Other Rape     306
#            2002  Total Rape Victims        324
#                  Victims of Incest Rape      0
#                  Victims of Other Rape     324
#            2003  Total Rape Victims        342
#                  Victims of Incest Rape      0
#                  Victims of Other Rape     342
#            2004  Total Rape Victims        480
#                  Victims of Incest Rape      3
#                  Victims of Other Rape     477
#            2005  Total Rape Victims        486
#                  Victims of Incest Rape      0
#                  Victims of Other Rape     486
#            2006  Total Rape Victims        571
#                  Victims of Incest Rape     12
#                  Victims of Other Rape     559
#            2007  Total Rape Victims        471
# ...

# %% [markdown]
# Analyzing the data Karnataka

# %%
Karnataka=df[(df['Area_Name']=='Karnataka')]
Karnataka
# Out:
#      Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 480  Karnataka  2001      Total Rape Victims                  293
# 481  Karnataka  2001  Victims of Incest Rape                    5
# 482  Karnataka  2001   Victims of Other Rape                  288
# 483  Karnataka  2002      Total Rape Victims                  292
# 484  Karnataka  2002  Victims of Incest Rape                    4
# 485  Karnataka  2002   Victims of Other Rape                  288
# 486  Karnataka  2003      Total Rape Victims                  321
# 487  Karnataka  2003  Victims of Incest Rape                    1
# 488  Karnataka  2003   Victims of Other Rape                  320
# 489  Karnataka  2004      Total Rape Victims                  291
# 490  Karnataka  2004  Victims of Incest Rape                    7
# 491  Karnataka  2004   Victims of Other Rape                  284
# 492  Karnataka  2005      Total Rape Victims                  343
# ...

# %%
Karnataka.head()
# Out:
#      Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 480  Karnataka  2001      Total Rape Victims                  293
# 481  Karnataka  2001  Victims of Incest Rape                    5
# 482  Karnataka  2001   Victims of Other Rape                  288
# 483  Karnataka  2002      Total Rape Victims                  292
# 484  Karnataka  2002  Victims of Incest Rape                    4
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 480                     0                         63
# 481                     0                          0
# 482                     0                         63
# 483                     1                         10
# 484                     0                          1
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 480                         62                        123
# 481                          1                          1
# 482                         61                        122
# ...

# %%
karnatakagroup =Karnataka.groupby(['Area_Name','Year','Subgroup']).mean()
karnatakagroup
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Karnataka 2001 Total Rape Victims                      293
#                Victims of Incest Rape                    5
#                Victims of Other Rape                   288
#           2002 Total Rape Victims                      292
#                Victims of Incest Rape                    4
#                Victims of Other Rape                   288
#           2003 Total Rape Victims                      321
#                Victims of Incest Rape                    1
#                Victims of Other Rape                   320
#           2004 Total Rape Victims                      291
#                Victims of Incest Rape                    7
#                Victims of Other Rape                   284
#           2005 Total Rape Victims                      343
#                Victims of Incest Rape                    5
# ...

# %%
karnatakagroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Karnataka 2001 Total Rape Victims                      293
#                Victims of Incest Rape                    5
#                Victims of Other Rape                   288
#           2002 Total Rape Victims                      292
#                Victims of Incest Rape                    4
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Karnataka 2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         1
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Karnataka 2001 Total Rape Victims                             63
# ...

# %%
sns.countplot(x='Victims_Upto_10_Yrs',data=Karnataka)

# %%
karnatakagroup.sum(axis=0)
sumk=pd.DataFrame(karnatakagroup.sum(axis=0))
sumk.columns=['Karnataka']
karnatakagroup.sum(axis=0)
#The total cases in Karnataka for the 10 years in 7834. The most cases aggregating to 5014 are reported between 18-30 yrs.
#Followed by 30-50 yrs - 976, 14-18yrs - 770, 10-14 yrs -632 and less than 10 yrs - 374
# Out:
# Rape_Cases_Reported          7834
# Victims_Above_50_Yrs           68
# Victims_Between_10-14_Yrs     632
# Victims_Between_14-18_Yrs     770
# Victims_Between_18-30_Yrs    5014
# Victims_Between_30-50_Yrs     976
# Victims_of_Rape_Total        7834
# Victims_Upto_10_Yrs           374
# dtype: int64

# %%
karnatakagroup.sum(axis=1)

#The total cases have been increased from 879 in 2001 to 1752 in 2010. The total % of increase is 99.31 since 2001. Or it has increased to 1.99 times.
#The victims of in
# Out:
# Area_Name  Year  Subgroup
# Karnataka  2001  Total Rape Victims         879
#                  Victims of Incest Rape      15
#                  Victims of Other Rape      864
#            2002  Total Rape Victims         876
#                  Victims of Incest Rape      12
#                  Victims of Other Rape      864
#            2003  Total Rape Victims         963
#                  Victims of Incest Rape       3
#                  Victims of Other Rape      960
#            2004  Total Rape Victims         873
#                  Victims of Incest Rape      21
#                  Victims of Other Rape      852
#            2005  Total Rape Victims        1029
#                  Victims of Incest Rape      15
#                  Victims of Other Rape     1014
#            2006  Total Rape Victims        1200
#                  Victims of Incest Rape       6
#                  Victims of Other Rape     1194
#            2007  Total Rape Victims        1308
# ...

# %% [markdown]
# Analysis of Bihar

# %%
Bihar=df[(df['Area_Name']=='Bihar')]
Bihar
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 120     Bihar  2001      Total Rape Victims                  888
# 121     Bihar  2001  Victims of Incest Rape                    8
# 122     Bihar  2001   Victims of Other Rape                  880
# 123     Bihar  2002      Total Rape Victims                 1040
# 124     Bihar  2002  Victims of Incest Rape                    3
# 125     Bihar  2002   Victims of Other Rape                 1037
# 126     Bihar  2003      Total Rape Victims                  985
# 127     Bihar  2003  Victims of Incest Rape                    1
# 128     Bihar  2003   Victims of Other Rape                  984
# 129     Bihar  2004      Total Rape Victims                 1390
# 130     Bihar  2004  Victims of Incest Rape                    6
# 131     Bihar  2004   Victims of Other Rape                 1384
# 132     Bihar  2005      Total Rape Victims                 1147
# ...

# %%
Bihar.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 120     Bihar  2001      Total Rape Victims                  888
# 121     Bihar  2001  Victims of Incest Rape                    8
# 122     Bihar  2001   Victims of Other Rape                  880
# 123     Bihar  2002      Total Rape Victims                 1040
# 124     Bihar  2002  Victims of Incest Rape                    3
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 120                     0                         15
# 121                     0                          2
# 122                     0                         13
# 123                     0                          2
# 124                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 120                        198                        562
# 121                          5                          1
# 122                        193                        561
# ...

# %%
bihargroup=Bihar.groupby(['Area_Name','Year','Subgroup']).mean()
bihargroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Bihar     2001 Total Rape Victims                      888
#                Victims of Incest Rape                    8
#                Victims of Other Rape                   880
#           2002 Total Rape Victims                     1040
#                Victims of Incest Rape                    3
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Bihar     2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Bihar     2001 Total Rape Victims                             15
# ...

# %%
bihargroup.sum(axis=0)
sumb=pd.DataFrame(bihargroup.sum(axis=0))
sumb.columns=['Bihar']
bihargroup.sum(axis=0)
#The no. of rape cases are 22526 wherein the highest no of victims 16988 are in the range 18-30 years, followed by 30-50 yrs 4194
#This is followed by between 14-18 yrs 1000 and 10-14 yrs 204.
# Out:
# Rape_Cases_Reported          22526
# Victims_Above_50_Yrs            78
# Victims_Between_10-14_Yrs      204
# Victims_Between_14-18_Yrs     1000
# Victims_Between_18-30_Yrs    16988
# Victims_Between_30-50_Yrs     4194
# Victims_of_Rape_Total        22526
# Victims_Upto_10_Yrs             62
# dtype: int64

# %%
bihargroup.sum(axis=1)
#The no of rapes for the ten years have been almost in the same range except for 2004, 2007 and 2008 which saw significant increase in cases
# Out:
# Area_Name  Year  Subgroup
# Bihar      2001  Total Rape Victims        2664
#                  Victims of Incest Rape      24
#                  Victims of Other Rape     2640
#            2002  Total Rape Victims        3120
#                  Victims of Incest Rape       9
#                  Victims of Other Rape     3111
#            2003  Total Rape Victims        2955
#                  Victims of Incest Rape       3
#                  Victims of Other Rape     2952
#            2004  Total Rape Victims        4170
#                  Victims of Incest Rape      18
#                  Victims of Other Rape     4152
#            2005  Total Rape Victims        3441
#                  Victims of Incest Rape      30
#                  Victims of Other Rape     3411
#            2006  Total Rape Victims        3696
#                  Victims of Incest Rape      21
#                  Victims of Other Rape     3675
#            2007  Total Rape Victims        4665
# ...

# %%
sns.countplot(x='Victims_Upto_10_Yrs',data=Bihar)

# %% [markdown]
# Chandigarh Analysis

# %%
Chandigarh=df[(df['Area_Name']=='Chandigarh')]
Chandigarh
# Out:
#       Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 150  Chandigarh  2001      Total Rape Victims                   18
# 151  Chandigarh  2001  Victims of Incest Rape                    2
# 152  Chandigarh  2001   Victims of Other Rape                   16
# 153  Chandigarh  2002      Total Rape Victims                   18
# 154  Chandigarh  2002  Victims of Incest Rape                    2
# 155  Chandigarh  2002   Victims of Other Rape                   16
# 156  Chandigarh  2003      Total Rape Victims                   18
# 157  Chandigarh  2003  Victims of Incest Rape                    1
# 158  Chandigarh  2003   Victims of Other Rape                   17
# 159  Chandigarh  2004      Total Rape Victims                   19
# 160  Chandigarh  2004  Victims of Incest Rape                    1
# 161  Chandigarh  2004   Victims of Other Rape                   18
# 162  Chandigarh  2005      Total Rape Victims                   33
# ...

# %%
Chandigarh.head()
# Out:
#       Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 150  Chandigarh  2001      Total Rape Victims                   18
# 151  Chandigarh  2001  Victims of Incest Rape                    2
# 152  Chandigarh  2001   Victims of Other Rape                   16
# 153  Chandigarh  2002      Total Rape Victims                   18
# 154  Chandigarh  2002  Victims of Incest Rape                    2
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 150                     0                          8
# 151                     0                          0
# 152                     0                          8
# 153                     0                          4
# 154                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 150                          4                          4
# 151                          0                          2
# 152                          4                          2
# ...

# %%
Chandigarhgroup=Chandigarh.groupby(['Area_Name','Year','Subgroup']).mean()
Chandigarhgroup
# Out:
#                                         Rape_Cases_Reported  \
# Area_Name  Year Subgroup
# Chandigarh 2001 Total Rape Victims                       18
#                 Victims of Incest Rape                    2
#                 Victims of Other Rape                    16
#            2002 Total Rape Victims                       18
#                 Victims of Incest Rape                    2
#                 Victims of Other Rape                    16
#            2003 Total Rape Victims                       18
#                 Victims of Incest Rape                    1
#                 Victims of Other Rape                    17
#            2004 Total Rape Victims                       19
#                 Victims of Incest Rape                    1
#                 Victims of Other Rape                    18
#            2005 Total Rape Victims                       33
#                 Victims of Incest Rape                    1
# ...

# %%
Chandigarhgroup.head()
# Out:
#                                         Rape_Cases_Reported  \
# Area_Name  Year Subgroup
# Chandigarh 2001 Total Rape Victims                       18
#                 Victims of Incest Rape                    2
#                 Victims of Other Rape                    16
#            2002 Total Rape Victims                       18
#                 Victims of Incest Rape                    2
#
#                                         Victims_Above_50_Yrs  \
# Area_Name  Year Subgroup
# Chandigarh 2001 Total Rape Victims                         0
#                 Victims of Incest Rape                     0
#                 Victims of Other Rape                      0
#            2002 Total Rape Victims                         0
#                 Victims of Incest Rape                     0
#
#                                         Victims_Between_10-14_Yrs  \
# Area_Name  Year Subgroup
# Chandigarh 2001 Total Rape Victims                              8
# ...

# %%
Chandigarhgroup.sum(axis=0)
sumc=pd.DataFrame(Chandigarhgroup.sum(axis=0))
sumc.columns=['Chandigarh']
Chandigarhgroup.sum(axis=0)
#The total no of cases is 454 in whihc highest is from 18-30 yrs - 150 and 14-18 yrs - 104
# Out:
# Rape_Cases_Reported          454
# Victims_Above_50_Yrs           0
# Victims_Between_10-14_Yrs     92
# Victims_Between_14-18_Yrs    104
# Victims_Between_18-30_Yrs    150
# Victims_Between_30-50_Yrs     48
# Victims_of_Rape_Total        456
# Victims_Upto_10_Yrs           62
# dtype: int64

# %%
Chandigarhgroup.sum(axis=1)
#There is no much significant increase in the no of cases in ten years. It has increased from 56 in 2001 to 93 in 2010.
#There has no incest rape in 2009 and 2010
# Out:
# Area_Name   Year  Subgroup
# Chandigarh  2001  Total Rape Victims        56
#                   Victims of Incest Rape     6
#                   Victims of Other Rape     50
#             2002  Total Rape Victims        54
#                   Victims of Incest Rape     6
#                   Victims of Other Rape     48
#             2003  Total Rape Victims        54
#                   Victims of Incest Rape     3
#                   Victims of Other Rape     51
#             2004  Total Rape Victims        57
#                   Victims of Incest Rape     3
#                   Victims of Other Rape     54
#             2005  Total Rape Victims        99
#                   Victims of Incest Rape     3
#                   Victims of Other Rape     96
#             2006  Total Rape Victims        57
#                   Victims of Incest Rape    15
#                   Victims of Other Rape     42
#             2007  Total Rape Victims        66
# ...

# %%
sns.countplot(x='Victims_Upto_10_Yrs',data=Chandigarh)

# %% [markdown]
# Delhi Analysis

# %%
Delhi=df[(df['Area_Name']=='Delhi')]
Delhi
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 270     Delhi  2001      Total Rape Victims                  381
# 271     Delhi  2001  Victims of Incest Rape                    9
# 272     Delhi  2001   Victims of Other Rape                  372
# 273     Delhi  2002      Total Rape Victims                  403
# 274     Delhi  2002  Victims of Incest Rape                   32
# 275     Delhi  2002   Victims of Other Rape                  371
# 276     Delhi  2003      Total Rape Victims                  490
# 277     Delhi  2003  Victims of Incest Rape                   21
# 278     Delhi  2003   Victims of Other Rape                  469
# 279     Delhi  2004      Total Rape Victims                  551
# 280     Delhi  2004  Victims of Incest Rape                   16
# 281     Delhi  2004   Victims of Other Rape                  535
# 282     Delhi  2005      Total Rape Victims                  658
# ...

# %%
Delhi.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 270     Delhi  2001      Total Rape Victims                  381
# 271     Delhi  2001  Victims of Incest Rape                    9
# 272     Delhi  2001   Victims of Other Rape                  372
# 273     Delhi  2002      Total Rape Victims                  403
# 274     Delhi  2002  Victims of Incest Rape                   32
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 270                     0                         81
# 271                     0                          3
# 272                     0                         78
# 273                     0                         54
# 274                     0                          6
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 270                        154                         59
# 271                          2                          1
# 272                        152                         58
# ...

# %%
Delhigroup=Delhi.groupby(['Area_Name','Year','Subgroup']).mean()
Delhigroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Delhi     2001 Total Rape Victims                      381
#                Victims of Incest Rape                    9
#                Victims of Other Rape                   372
#           2002 Total Rape Victims                      403
#                Victims of Incest Rape                   32
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Delhi     2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Delhi     2001 Total Rape Victims                             81
# ...

# %%
Delhigroup.sum(axis=0)
sumde=pd.DataFrame(Delhigroup.sum(axis=0))
sumde.columns=['Delhi']
Delhigroup.sum(axis=0)
# Out:
# Rape_Cases_Reported          10292
# Victims_Above_50_Yrs            26
# Victims_Between_10-14_Yrs     1764
# Victims_Between_14-18_Yrs     2812
# Victims_Between_18-30_Yrs     4118
# Victims_Between_30-50_Yrs      534
# Victims_of_Rape_Total        10342
# Victims_Upto_10_Yrs           1088
# dtype: int64

# %%
Delhigroup.sum(axis=1)
# Out:
# Area_Name  Year  Subgroup
# Delhi      2001  Total Rape Victims        1147
#                  Victims of Incest Rape      27
#                  Victims of Other Rape     1120
#            2002  Total Rape Victims        1217
#                  Victims of Incest Rape      96
#                  Victims of Other Rape     1121
#            2003  Total Rape Victims        1470
#                  Victims of Incest Rape      63
#                  Victims of Other Rape     1407
#            2004  Total Rape Victims        1653
#                  Victims of Incest Rape      48
#                  Victims of Other Rape     1605
#            2005  Total Rape Victims        1990
#                  Victims of Incest Rape      96
#                  Victims of Other Rape     1894
#            2006  Total Rape Victims        1875
#                  Victims of Incest Rape      78
#                  Victims of Other Rape     1797
#            2007  Total Rape Victims        1802
# ...

# %%
sns.countplot(x='Victims_Upto_10_Yrs',data=Delhigroup)

# %% [markdown]
# Nagaland Analysis

# %%
Nagaland=df[(df['Area_Name']=='Nagaland')]
Nagaland
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 720  Nagaland  2001      Total Rape Victims                   17
# 721  Nagaland  2001  Victims of Incest Rape                    1
# 722  Nagaland  2001   Victims of Other Rape                   16
# 723  Nagaland  2002      Total Rape Victims                   17
# 724  Nagaland  2002  Victims of Incest Rape                    0
# 725  Nagaland  2002   Victims of Other Rape                   17
# 726  Nagaland  2003      Total Rape Victims                   14
# 727  Nagaland  2003  Victims of Incest Rape                    0
# 728  Nagaland  2003   Victims of Other Rape                   14
# 729  Nagaland  2004      Total Rape Victims                   18
# 730  Nagaland  2004  Victims of Incest Rape                    0
# 731  Nagaland  2004   Victims of Other Rape                   18
# 732  Nagaland  2005      Total Rape Victims                   17
# ...

# %%
Nagaland.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 720  Nagaland  2001      Total Rape Victims                   17
# 721  Nagaland  2001  Victims of Incest Rape                    1
# 722  Nagaland  2001   Victims of Other Rape                   16
# 723  Nagaland  2002      Total Rape Victims                   17
# 724  Nagaland  2002  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 720                     0                          0
# 721                     0                          0
# 722                     0                          0
# 723                     0                          1
# 724                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 720                          8                          6
# 721                          0                          0
# 722                          8                          6
# ...

# %%
Nagalandgroup=Nagaland.groupby(['Area_Name','Year','Subgroup']).mean()
Nagalandgroup
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Nagaland  2001 Total Rape Victims                       17
#                Victims of Incest Rape                    1
#                Victims of Other Rape                    16
#           2002 Total Rape Victims                       17
#                Victims of Incest Rape                    0
#                Victims of Other Rape                    17
#           2003 Total Rape Victims                       14
#                Victims of Incest Rape                    0
#                Victims of Other Rape                    14
#           2004 Total Rape Victims                       18
#                Victims of Incest Rape                    0
#                Victims of Other Rape                    18
#           2005 Total Rape Victims                       17
#                Victims of Incest Rape                    0
# ...

# %%
Nagalandgroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Nagaland  2001 Total Rape Victims                       17
#                Victims of Incest Rape                    1
#                Victims of Other Rape                    16
#           2002 Total Rape Victims                       17
#                Victims of Incest Rape                    0
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Nagaland  2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Nagaland  2001 Total Rape Victims                              0
# ...

# %%
sumna=pd.DataFrame(Nagalandgroup.sum(axis=0))
sumna
sumna.columns=['Nagaland']
Nagalandgroup.sum(axis=0)
#Nagaland has reported 352 cases during the decade out of which upto 10 years victims are 26 and 238 are between 18 to 30.
# Out:
# Rape_Cases_Reported          352
# Victims_Above_50_Yrs           0
# Victims_Between_10-14_Yrs      6
# Victims_Between_14-18_Yrs     40
# Victims_Between_18-30_Yrs    238
# Victims_Between_30-50_Yrs     42
# Victims_of_Rape_Total        352
# Victims_Upto_10_Yrs           26
# dtype: int64

# %%
Nagalandgroup.sum(axis=1)
#Throughout the decade the no. of victims are around 50
# Out:
# Area_Name  Year  Subgroup
# Nagaland   2001  Total Rape Victims        51
#                  Victims of Incest Rape     3
#                  Victims of Other Rape     48
#            2002  Total Rape Victims        51
#                  Victims of Incest Rape     0
#                  Victims of Other Rape     51
#            2003  Total Rape Victims        42
#                  Victims of Incest Rape     0
#                  Victims of Other Rape     42
#            2004  Total Rape Victims        54
#                  Victims of Incest Rape     0
#                  Victims of Other Rape     54
#            2005  Total Rape Victims        51
#                  Victims of Incest Rape     0
#                  Victims of Other Rape     51
#            2006  Total Rape Victims        69
#                  Victims of Incest Rape     0
#                  Victims of Other Rape     69
#            2007  Total Rape Victims        39
#                  Victims of Incest Rape     3
# ...

# %%
sns.countplot(x='Victims_Upto_10_Yrs',data=Nagalandgroup)

# %% [markdown]
# Assam Anaysis

# %%
Assam=df[(df['Area_Name']=='Assam')]
Assam
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 90      Assam  2001      Total Rape Victims                  817
# 91      Assam  2001  Victims of Incest Rape                    8
# 92      Assam  2001   Victims of Other Rape                  809
# 93      Assam  2002      Total Rape Victims                  970
# 94      Assam  2002  Victims of Incest Rape                   10
# 95      Assam  2002   Victims of Other Rape                  960
# 96      Assam  2003      Total Rape Victims                 1095
# 97      Assam  2003  Victims of Incest Rape                   19
# 98      Assam  2003   Victims of Other Rape                 1076
# 99      Assam  2004      Total Rape Victims                 1171
# 100     Assam  2004  Victims of Incest Rape                   15
# 101     Assam  2004   Victims of Other Rape                 1156
# 102     Assam  2005      Total Rape Victims                 1238
# ...

# %%
Assam.head()
# Out:
#    Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 90     Assam  2001      Total Rape Victims                  817
# 91     Assam  2001  Victims of Incest Rape                    8
# 92     Assam  2001   Victims of Other Rape                  809
# 93     Assam  2002      Total Rape Victims                  970
# 94     Assam  2002  Victims of Incest Rape                   10
#
#     Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 90                     2                         73
# 91                     0                          1
# 92                     2                         72
# 93                     0                          0
# 94                     0                          0
#
#     Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 90                        245                        370
# 91                          7                          0
# 92                        238                        370
# ...

# %%
Assamgroup=Assam.groupby(['Area_Name','Year','Subgroup']).mean()
Assamgroup
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Assam     2001 Total Rape Victims                      817
#                Victims of Incest Rape                    8
#                Victims of Other Rape                   809
#           2002 Total Rape Victims                      970
#                Victims of Incest Rape                   10
#                Victims of Other Rape                   960
#           2003 Total Rape Victims                     1095
#                Victims of Incest Rape                   19
#                Victims of Other Rape                  1076
#           2004 Total Rape Victims                     1171
#                Victims of Incest Rape                   15
#                Victims of Other Rape                  1156
#           2005 Total Rape Victims                     1238
#                Victims of Incest Rape                    7
# ...

# %%
sumas=pd.DataFrame(Assamgroup.sum(axis=0))
sumas
sumas.columns=['Assam']
Assamgroup.sum(axis=0)
# Out:
# Rape_Cases_Reported          25524
# Victims_Above_50_Yrs           190
# Victims_Between_10-14_Yrs      306
# Victims_Between_14-18_Yrs      818
# Victims_Between_18-30_Yrs    17014
# Victims_Between_30-50_Yrs     7104
# Victims_of_Rape_Total        25524
# Victims_Upto_10_Yrs             92
# dtype: int64

# %%
Assamgroup.sum(axis=1)
# Out:
# Area_Name  Year  Subgroup
# Assam      2001  Total Rape Victims        2451
#                  Victims of Incest Rape      24
#                  Victims of Other Rape     2427
#            2002  Total Rape Victims        2910
#                  Victims of Incest Rape      30
#                  Victims of Other Rape     2880
#            2003  Total Rape Victims        3285
#                  Victims of Incest Rape      57
#                  Victims of Other Rape     3228
#            2004  Total Rape Victims        3513
#                  Victims of Incest Rape      45
#                  Victims of Other Rape     3468
#            2005  Total Rape Victims        3714
#                  Victims of Incest Rape      21
#                  Victims of Other Rape     3693
#            2006  Total Rape Victims        3732
#                  Victims of Incest Rape      36
#                  Victims of Other Rape     3696
#            2007  Total Rape Victims        4311
# ...

# %% [markdown]
# Uttarakhand Analysis

# %%
Uttarakhand=df[(df['Area_Name']=='Uttarakhand')]
Uttarakhand.head()
# Out:
#        Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 990  Uttarakhand  2001      Total Rape Victims                   74
# 991  Uttarakhand  2001  Victims of Incest Rape                    0
# 992  Uttarakhand  2001   Victims of Other Rape                   74
# 993  Uttarakhand  2002      Total Rape Victims                   89
# 994  Uttarakhand  2002  Victims of Incest Rape                   16
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 990                     0                          7
# 991                     0                          0
# 992                     0                          7
# 993                     0                          4
# 994                     0                          4
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 990                         16                         38
# 991                          0                          0
# ...

# %%
Uttarakhandgroup=Uttarakhand.groupby(['Area_Name','Year','Subgroup']).mean()
Uttarakhandgroup.head()
# Out:
#                                          Rape_Cases_Reported  \
# Area_Name   Year Subgroup
# Uttarakhand 2001 Total Rape Victims                       74
#                  Victims of Incest Rape                    0
#                  Victims of Other Rape                    74
#             2002 Total Rape Victims                       89
#                  Victims of Incest Rape                   16
#
#                                          Victims_Above_50_Yrs  \
# Area_Name   Year Subgroup
# Uttarakhand 2001 Total Rape Victims                         0
#                  Victims of Incest Rape                     0
#                  Victims of Other Rape                      0
#             2002 Total Rape Victims                         0
#                  Victims of Incest Rape                     0
#
#                                          Victims_Between_10-14_Yrs  \
# Area_Name   Year Subgroup
# Uttarakhand 2001 Total Rape Victims                              7
# ...

# %%
sumuk=pd.DataFrame(Uttarakhandgroup.sum(axis=0))
sumuk
sumuk.columns=['Uttarakhand']
Uttarakhandgroup.sum(axis=0)
# Out:
# Rape_Cases_Reported          2202
# Victims_Above_50_Yrs            0
# Victims_Between_10-14_Yrs     100
# Victims_Between_14-18_Yrs     160
# Victims_Between_18-30_Yrs    1558
# Victims_Between_30-50_Yrs     346
# Victims_of_Rape_Total        2202
# Victims_Upto_10_Yrs            38
# dtype: int64

# %%
Uttarakhandgroup.sum(axis=1)
# Out:
# Area_Name    Year  Subgroup
# Uttarakhand  2001  Total Rape Victims        222
#                    Victims of Incest Rape      0
#                    Victims of Other Rape     222
#              2002  Total Rape Victims        267
#                    Victims of Incest Rape     48
#                    Victims of Other Rape     219
#              2003  Total Rape Victims        321
#                    Victims of Incest Rape      6
#                    Victims of Other Rape     315
#              2004  Total Rape Victims        345
#                    Victims of Incest Rape     39
#                    Victims of Other Rape     306
#              2005  Total Rape Victims        399
#                    Victims of Incest Rape      9
#                    Victims of Other Rape     390
#              2006  Total Rape Victims        441
#                    Victims of Incest Rape     18
#                    Victims of Other Rape     423
#              2007  Total Rape Victims        351
# ...

# %% [markdown]
# Dadra & Nagar Haveli Analysis

# %%
Dadra=df[(df['Area_Name']=='Dadra & Nagar Haveli')]
Dadra.head()
# Out:
#                 Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 210  Dadra & Nagar Haveli  2001      Total Rape Victims                    6
# 211  Dadra & Nagar Haveli  2001  Victims of Incest Rape                    0
# 212  Dadra & Nagar Haveli  2001   Victims of Other Rape                    6
# 213  Dadra & Nagar Haveli  2002      Total Rape Victims                    4
# 214  Dadra & Nagar Haveli  2002  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 210                     0                          0
# 211                     0                          0
# 212                     0                          0
# 213                     0                          1
# 214                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 210                          3                          3
# 211                          0                          0
# ...

# %%
Dadragroup=Dadra.groupby(['Area_Name','Year','Subgroup']).mean()
Dadragroup.head()
# Out:
#                                                   Rape_Cases_Reported  \
# Area_Name            Year Subgroup
# Dadra & Nagar Haveli 2001 Total Rape Victims                        6
#                           Victims of Incest Rape                    0
#                           Victims of Other Rape                     6
#                      2002 Total Rape Victims                        4
#                           Victims of Incest Rape                    0
#
#                                                   Victims_Above_50_Yrs  \
# Area_Name            Year Subgroup
# Dadra & Nagar Haveli 2001 Total Rape Victims                         0
#                           Victims of Incest Rape                     0
#                           Victims of Other Rape                      0
#                      2002 Total Rape Victims                         0
#                           Victims of Incest Rape                     0
#
# ...

# %%
sumda=pd.DataFrame(Dadragroup.sum(axis=0))
sumda
sumda.columns=['Dadra & Nagar Haveli']
Dadragroup.sum(axis=0)
# Out:
# Rape_Cases_Reported          98
# Victims_Above_50_Yrs          0
# Victims_Between_10-14_Yrs    16
# Victims_Between_14-18_Yrs    26
# Victims_Between_18-30_Yrs    44
# Victims_Between_30-50_Yrs     2
# Victims_of_Rape_Total        98
# Victims_Upto_10_Yrs          10
# dtype: int64

# %%
Dadragroup.sum(axis=1)
# Out:
# Area_Name             Year  Subgroup
# Dadra & Nagar Haveli  2001  Total Rape Victims        18
#                             Victims of Incest Rape     0
#                             Victims of Other Rape     18
#                       2002  Total Rape Victims        12
#                             Victims of Incest Rape     0
#                             Victims of Other Rape     12
#                       2003  Total Rape Victims         3
#                             Victims of Incest Rape     0
#                             Victims of Other Rape      3
#                       2004  Total Rape Victims        21
#                             Victims of Incest Rape     0
#                             Victims of Other Rape     21
#                       2005  Total Rape Victims        15
#                             Victims of Incest Rape     0
#                             Victims of Other Rape     15
#                       2006  Total Rape Victims        18
# ...

# %% [markdown]
# Himachal Pradesh Analysis

# %%
HP=df[(df['Area_Name']=='Himachal Pradesh')]
HP.head()
# Out:
#             Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 390  Himachal Pradesh  2001      Total Rape Victims                  124
# 391  Himachal Pradesh  2001  Victims of Incest Rape                    0
# 392  Himachal Pradesh  2001   Victims of Other Rape                  124
# 393  Himachal Pradesh  2002      Total Rape Victims                  137
# 394  Himachal Pradesh  2002  Victims of Incest Rape                    1
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 390                     2                         15
# 391                     0                          0
# 392                     2                         15
# 393                     4                          5
# 394                     0                          1
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 390                         43                         35
# 391                          0                          0
# ...

# %%
HPgroup=HP.groupby(['Area_Name','Year','Subgroup']).mean()
HPgroup.head()
# Out:
#                                               Rape_Cases_Reported  \
# Area_Name        Year Subgroup
# Himachal Pradesh 2001 Total Rape Victims                      124
#                       Victims of Incest Rape                    0
#                       Victims of Other Rape                   124
#                  2002 Total Rape Victims                      137
#                       Victims of Incest Rape                    1
#
#                                               Victims_Above_50_Yrs  \
# Area_Name        Year Subgroup
# Himachal Pradesh 2001 Total Rape Victims                         2
#                       Victims of Incest Rape                     0
#                       Victims of Other Rape                      2
#                  2002 Total Rape Victims                         4
#                       Victims of Incest Rape                     0
#
#                                               Victims_Between_10-14_Yrs  \
# ...

# %%
sumHP=pd.DataFrame(HPgroup.sum(axis=0))
sumHP
sumHP.columns=['Himachal Pradesh']
HPgroup.sum(axis=0)
#There has been 2906 cases out of which 1272 are between 18-30 yrs. 186 are below 10 yrs.
# Out:
# Rape_Cases_Reported          2906
# Victims_Above_50_Yrs           36
# Victims_Between_10-14_Yrs     276
# Victims_Between_14-18_Yrs     702
# Victims_Between_18-30_Yrs    1272
# Victims_Between_30-50_Yrs     434
# Victims_of_Rape_Total        2906
# Victims_Upto_10_Yrs           186
# dtype: int64

# %%
HPgroup.sum(axis=1)
#The no. of cases has increased from 372 in 2001 to 480 in 2010
# Out:
# Area_Name         Year  Subgroup
# Himachal Pradesh  2001  Total Rape Victims        372
#                         Victims of Incest Rape      0
#                         Victims of Other Rape     372
#                   2002  Total Rape Victims        411
#                         Victims of Incest Rape      3
#                         Victims of Other Rape     408
#                   2003  Total Rape Victims        378
#                         Victims of Incest Rape      6
#                         Victims of Other Rape     372
#                   2004  Total Rape Victims        459
#                         Victims of Incest Rape     24
#                         Victims of Other Rape     435
#                   2005  Total Rape Victims        423
#                         Victims of Incest Rape     15
#                         Victims of Other Rape     408
#                   2006  Total Rape Victims        339
#                         Victims of Incest Rape     21
# ...

# %% [markdown]
# Jammu & Kashmir Analysis

# %%
JK=df[(df['Area_Name']=='Jammu & Kashmir')]
JK.head()
# Out:
#            Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 420  Jammu & Kashmir  2001      Total Rape Victims                  169
# 421  Jammu & Kashmir  2001  Victims of Incest Rape                    2
# 422  Jammu & Kashmir  2001   Victims of Other Rape                  167
# 423  Jammu & Kashmir  2002      Total Rape Victims                  192
# 424  Jammu & Kashmir  2002  Victims of Incest Rape                    3
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 420                     0                         24
# 421                     0                          0
# 422                     0                         24
# 423                     1                          0
# 424                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 420                         41                         84
# 421                          1                          1
# ...

# %%
JKgroup=JK.groupby(['Area_Name','Year','Subgroup']).mean()
JKgroup.head()
# Out:
#                                              Rape_Cases_Reported  \
# Area_Name       Year Subgroup
# Jammu & Kashmir 2001 Total Rape Victims                      169
#                      Victims of Incest Rape                    2
#                      Victims of Other Rape                   167
#                 2002 Total Rape Victims                      192
#                      Victims of Incest Rape                    3
#
#                                              Victims_Above_50_Yrs  \
# Area_Name       Year Subgroup
# Jammu & Kashmir 2001 Total Rape Victims                         0
#                      Victims of Incest Rape                     0
#                      Victims of Other Rape                      0
#                 2002 Total Rape Victims                         1
#                      Victims of Incest Rape                     0
#
#                                              Victims_Between_10-14_Yrs  \
# Area_Name       Year Subgroup
# ...

# %%
sumJK=pd.DataFrame(JKgroup.sum(axis=0))
sumJK
sumJK.columns=['Jammu & Kashmir']
JKgroup.sum(axis=0)
#The more no of victims ie 3164 are in the age 18-30, followed by 1036 in 30-50 yrs. below 10 yrs, 12 are victims and above 50, 12 are victims
# Out:
# Rape_Cases_Reported          4460
# Victims_Above_50_Yrs           12
# Victims_Between_10-14_Yrs      80
# Victims_Between_14-18_Yrs     152
# Victims_Between_18-30_Yrs    3164
# Victims_Between_30-50_Yrs    1036
# Victims_of_Rape_Total        4456
# Victims_Upto_10_Yrs            12
# dtype: int64

# %%
JKgroup.sum(axis=1)
#The total no of victims have increased from 507 in 2001 to 735 in 2010
# Out:
# Area_Name        Year  Subgroup
# Jammu & Kashmir  2001  Total Rape Victims        507
#                        Victims of Incest Rape      6
#                        Victims of Other Rape     501
#                  2002  Total Rape Victims        576
#                        Victims of Incest Rape      9
#                        Victims of Other Rape     567
#                  2003  Total Rape Victims        633
#                        Victims of Incest Rape      6
#                        Victims of Other Rape     627
#                  2004  Total Rape Victims        654
#                        Victims of Incest Rape      3
#                        Victims of Other Rape     651
#                  2005  Total Rape Victims        603
#                        Victims of Incest Rape      0
#                        Victims of Other Rape     603
#                  2006  Total Rape Victims        750
#                        Victims of Incest Rape      0
# ...

# %% [markdown]
# Kerala Analysis

# %%
Kerala=df[(df['Area_Name']=='Kerala')]
Kerala.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 510    Kerala  2001      Total Rape Victims                  562
# 511    Kerala  2001  Victims of Incest Rape                    4
# 512    Kerala  2001   Victims of Other Rape                  558
# 513    Kerala  2002      Total Rape Victims                  499
# 514    Kerala  2002  Victims of Incest Rape                    4
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 510                     1                         46
# 511                     1                          0
# 512                     0                         46
# 513                     3                         29
# 514                     0                          1
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 510                        126                        306
# 511                          1                          1
# 512                        125                        305
# ...

# %%
Keralagroup=Kerala.groupby(['Area_Name','Year','Subgroup']).mean()
Keralagroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Kerala    2001 Total Rape Victims                      562
#                Victims of Incest Rape                    4
#                Victims of Other Rape                   558
#           2002 Total Rape Victims                      499
#                Victims of Incest Rape                    4
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Kerala    2001 Total Rape Victims                         1
#                Victims of Incest Rape                     1
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         3
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Kerala    2001 Total Rape Victims                             46
# ...

# %%
sumke=pd.DataFrame(Keralagroup.sum(axis=0))
sumke
sumke.columns=['Kerala']
Keralagroup.sum(axis=0)
#out pf 10592 cases, 5460 cases are from 18-30 followed by 2264 from 14-18
# Out:
# Rape_Cases_Reported          10592
# Victims_Above_50_Yrs           120
# Victims_Between_10-14_Yrs      852
# Victims_Between_14-18_Yrs     2264
# Victims_Between_18-30_Yrs     5460
# Victims_Between_30-50_Yrs     1400
# Victims_of_Rape_Total        10616
# Victims_Upto_10_Yrs            520
# dtype: int64

# %%
Keralagroup.sum(axis=1)
#The annual wise victims are between 1500-1900
# Out:
# Area_Name  Year  Subgroup
# Kerala     2001  Total Rape Victims        1686
#                  Victims of Incest Rape      12
#                  Victims of Other Rape     1674
#            2002  Total Rape Victims        1497
#                  Victims of Incest Rape      12
#                  Victims of Other Rape     1485
#            2003  Total Rape Victims        1182
#                  Victims of Incest Rape      21
#                  Victims of Other Rape     1161
#            2004  Total Rape Victims        1440
#                  Victims of Incest Rape       9
#                  Victims of Other Rape     1431
#            2005  Total Rape Victims        1440
#                  Victims of Incest Rape      36
#                  Victims of Other Rape     1404
#            2006  Total Rape Victims        1811
#                  Victims of Incest Rape      84
#                  Victims of Other Rape     1727
#            2007  Total Rape Victims        1538
# ...

# %% [markdown]
# Jharkhand Anaysis

# %%
Jharkhand=df[(df['Area_Name']=='Jharkhand')]
Jharkhand.head()
# Out:
#      Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 450  Jharkhand  2001      Total Rape Victims                  567
# 451  Jharkhand  2001  Victims of Incest Rape                   12
# 452  Jharkhand  2001   Victims of Other Rape                  555
# 453  Jharkhand  2002      Total Rape Victims                  797
# 454  Jharkhand  2002  Victims of Incest Rape                   18
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 450                     0                          3
# 451                     0                          3
# 452                     0                          0
# 453                     0                          0
# 454                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 450                          4                        478
# 451                          4                          2
# 452                          0                        476
# ...

# %%
Jharkhandgroup=Jharkhand.groupby(['Area_Name','Year','Subgroup']).mean()
Jharkhandgroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Jharkhand 2001 Total Rape Victims                      567
#                Victims of Incest Rape                   12
#                Victims of Other Rape                   555
#           2002 Total Rape Victims                      797
#                Victims of Incest Rape                   18
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Jharkhand 2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Jharkhand 2001 Total Rape Victims                              3
# ...

# %%
sumjk=pd.DataFrame(Jharkhandgroup.sum(axis=0))
sumjk
sumjk.columns=['Jharkhand']
Jharkhandgroup.sum(axis=0)
#the major victims 11,276 are under age 18-30 yrs followed by 30-50 yrs
# Out:
# Rape_Cases_Reported          15126
# Victims_Above_50_Yrs            20
# Victims_Between_10-14_Yrs      156
# Victims_Between_14-18_Yrs      656
# Victims_Between_18-30_Yrs    11276
# Victims_Between_30-50_Yrs     2974
# Victims_of_Rape_Total        15126
# Victims_Upto_10_Yrs             44
# dtype: int64

# %%
Jharkhandgroup.sum(axis=1)
#Over the decade, the cases has been around 2200-2300
# Out:
# Area_Name  Year  Subgroup
# Jharkhand  2001  Total Rape Victims        1701
#                  Victims of Incest Rape      36
#                  Victims of Other Rape     1665
#            2002  Total Rape Victims        2391
#                  Victims of Incest Rape      54
#                  Victims of Other Rape     2337
#            2003  Total Rape Victims        2136
#                  Victims of Incest Rape      42
#                  Victims of Other Rape     2094
#            2004  Total Rape Victims        2391
#                  Victims of Incest Rape      54
#                  Victims of Other Rape     2337
#            2005  Total Rape Victims        2259
#                  Victims of Incest Rape     360
#                  Victims of Other Rape     1899
#            2006  Total Rape Victims        2397
#                  Victims of Incest Rape     282
#                  Victims of Other Rape     2115
#            2007  Total Rape Victims        2565
# ...

# %% [markdown]
# Goa Analysis

# %%
Goa=df[(df['Area_Name']=='Goa')]
Goa.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 300       Goa  2001      Total Rape Victims                   12
# 301       Goa  2001  Victims of Incest Rape                    0
# 302       Goa  2001   Victims of Other Rape                   12
# 303       Goa  2002      Total Rape Victims                   12
# 304       Goa  2002  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 300                     0                          7
# 301                     0                          0
# 302                     0                          7
# 303                     0                          3
# 304                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 300                          1                          0
# 301                          0                          0
# 302                          1                          0
# ...

# %%
Goagroup=Goa.groupby(['Area_Name','Year','Subgroup']).mean()
Goagroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Goa       2001 Total Rape Victims                       12
#                Victims of Incest Rape                    0
#                Victims of Other Rape                    12
#           2002 Total Rape Victims                       12
#                Victims of Incest Rape                    0
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Goa       2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Goa       2001 Total Rape Victims                              7
# ...

# %%
sumGoa=pd.DataFrame(Goagroup.sum(axis=0))
sumGoa
sumGoa.columns=['Goa']
Goagroup.sum(axis=0)
#The most of victims are from age group 14-18 followed by 18-30 and 10-14. Even the victims under 10 yrs are around 66 which is at the higher end.
# Out:
# Rape_Cases_Reported          532
# Victims_Above_50_Yrs          10
# Victims_Between_10-14_Yrs    120
# Victims_Between_14-18_Yrs    172
# Victims_Between_18-30_Yrs    138
# Victims_Between_30-50_Yrs     34
# Victims_of_Rape_Total        540
# Victims_Upto_10_Yrs           66
# dtype: int64

# %%
Goagroup.sum(axis=1)
# Out:
# Area_Name  Year  Subgroup
# Goa        2001  Total Rape Victims         36
#                  Victims of Incest Rape      0
#                  Victims of Other Rape      36
#            2002  Total Rape Victims         36
#                  Victims of Incest Rape      0
#                  Victims of Other Rape      36
#            2003  Total Rape Victims         95
#                  Victims of Incest Rape      0
#                  Victims of Other Rape      95
#            2004  Total Rape Victims        111
#                  Victims of Incest Rape      3
#                  Victims of Other Rape     108
#            2005  Total Rape Victims         60
#                  Victims of Incest Rape      3
#                  Victims of Other Rape      57
#            2006  Total Rape Victims         63
#                  Victims of Incest Rape      3
#                  Victims of Other Rape      60
#            2007  Total Rape Victims         60
# ...

# %% [markdown]
# Arunachal Pradesh

# %%
ARP=df[(df['Area_Name']=='Arunachal Pradesh')]
ARP.head()
# Out:
#             Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 60  Arunachal Pradesh  2001      Total Rape Victims                   33
# 61  Arunachal Pradesh  2001  Victims of Incest Rape                    0
# 62  Arunachal Pradesh  2001   Victims of Other Rape                   33
# 63  Arunachal Pradesh  2002      Total Rape Victims                   38
# 64  Arunachal Pradesh  2002  Victims of Incest Rape                    0
#
#     Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 60                     0                          0
# 61                     0                          0
# 62                     0                          0
# 63                     0                          0
# 64                     0                          0
#
#     Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 60                          1                         28
# 61                          0                          0
# ...

# %%
ARPgroup=ARP.groupby(['Area_Name','Year','Subgroup']).mean()
ARPgroup.head()
# Out:
#                                                Rape_Cases_Reported  \
# Area_Name         Year Subgroup
# Arunachal Pradesh 2001 Total Rape Victims                       33
#                        Victims of Incest Rape                    0
#                        Victims of Other Rape                    33
#                   2002 Total Rape Victims                       38
#                        Victims of Incest Rape                    0
#
#                                                Victims_Above_50_Yrs  \
# Area_Name         Year Subgroup
# Arunachal Pradesh 2001 Total Rape Victims                         0
#                        Victims of Incest Rape                     0
#                        Victims of Other Rape                      0
#                   2002 Total Rape Victims                         0
#                        Victims of Incest Rape                     0
#
#                                                Victims_Between_10-14_Yrs  \
# ...

# %%
sumARP=pd.DataFrame(ARPgroup.sum(axis=0))
sumARP
sumARP.columns=['Arunachal Pradesh']
ARPgroup.sum(axis=0)
#Arunachal pradesh has most victims in age 18-30. However, there are quite large percentage of victims in between 10-14 and below 10 yrs as well
# Out:
# Rape_Cases_Reported          824
# Victims_Above_50_Yrs           0
# Victims_Between_10-14_Yrs     96
# Victims_Between_14-18_Yrs     20
# Victims_Between_18-30_Yrs    632
# Victims_Between_30-50_Yrs     38
# Victims_of_Rape_Total        824
# Victims_Upto_10_Yrs           38
# dtype: int64

# %%
ARPgroup.sum(axis=1)
# Out:
# Area_Name          Year  Subgroup
# Arunachal Pradesh  2001  Total Rape Victims         99
#                          Victims of Incest Rape      0
#                          Victims of Other Rape      99
#                    2002  Total Rape Victims        114
#                          Victims of Incest Rape      0
#                          Victims of Other Rape     114
#                    2003  Total Rape Victims         93
#                          Victims of Incest Rape      0
#                          Victims of Other Rape      93
#                    2004  Total Rape Victims        126
#                          Victims of Incest Rape      0
#                          Victims of Other Rape     126
#                    2005  Total Rape Victims        105
#                          Victims of Incest Rape      0
#                          Victims of Other Rape     105
#                    2006  Total Rape Victims        111
# ...

# %% [markdown]
# Manipur Analysis

# %%
Manipur=df[(df['Area_Name']=='Manipur')]
Manipur.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 630   Manipur  2001      Total Rape Victims                   20
# 631   Manipur  2001  Victims of Incest Rape                    2
# 632   Manipur  2001   Victims of Other Rape                   18
# 633   Manipur  2002      Total Rape Victims                   14
# 634   Manipur  2002  Victims of Incest Rape                    3
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 630                     1                          1
# 631                     0                          0
# 632                     1                          1
# 633                     0                          0
# 634                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 630                          4                          9
# 631                          0                          0
# 632                          4                          9
# ...

# %%
Manipurgroup=Manipur.groupby(['Area_Name','Year','Subgroup']).mean()
Manipurgroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Manipur   2001 Total Rape Victims                       20
#                Victims of Incest Rape                    2
#                Victims of Other Rape                    18
#           2002 Total Rape Victims                       14
#                Victims of Incest Rape                    3
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Manipur   2001 Total Rape Victims                         1
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      1
#           2002 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Manipur   2001 Total Rape Victims                              1
# ...

# %%
summn=pd.DataFrame(Manipurgroup.sum(axis=0))
summn
summn.columns=['Manipur']
Manipurgroup.sum(axis=0)
#more than half of the victims are from 18-30 age. However siginificant portion of victims are from the age below 10 and from 10-18 yrs.
# Out:
# Rape_Cases_Reported          542
# Victims_Above_50_Yrs           6
# Victims_Between_10-14_Yrs     46
# Victims_Between_14-18_Yrs     80
# Victims_Between_18-30_Yrs    278
# Victims_Between_30-50_Yrs     70
# Victims_of_Rape_Total        546
# Victims_Upto_10_Yrs           66
# dtype: int64

# %%
Manipurgroup.sum(axis=1)
#The no of cases have increased from 60 in 2001 to 102 in 2010
# Out:
# Area_Name  Year  Subgroup
# Manipur    2001  Total Rape Victims         60
#                  Victims of Incest Rape      6
#                  Victims of Other Rape      54
#            2002  Total Rape Victims         42
#                  Victims of Incest Rape      9
#                  Victims of Other Rape      33
#            2003  Total Rape Victims         54
#                  Victims of Incest Rape      0
#                  Victims of Other Rape      54
#            2004  Total Rape Victims         93
#                  Victims of Incest Rape      0
#                  Victims of Other Rape      93
#            2005  Total Rape Victims         75
#                  Victims of Incest Rape      3
#                  Victims of Other Rape      72
#            2006  Total Rape Victims        124
#                  Victims of Incest Rape      0
#                  Victims of Other Rape     124
#            2007  Total Rape Victims         60
# ...

# %% [markdown]
# Haryana Analysis

# %%
Haryana=df[(df['Area_Name']=='Haryana')]
Haryana.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 360   Haryana  2001      Total Rape Victims                  398
# 361   Haryana  2001  Victims of Incest Rape                    0
# 362   Haryana  2001   Victims of Other Rape                  398
# 363   Haryana  2002      Total Rape Victims                  361
# 364   Haryana  2002  Victims of Incest Rape                   52
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 360                     3                         62
# 361                     0                          0
# 362                     3                         62
# 363                     1                         49
# 364                     0                          6
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 360                        125                        134
# 361                          0                          0
# 362                        125                        134
# ...

# %%
Haryanagroup=Haryana.groupby(['Area_Name','Year','Subgroup']).mean()
Haryanagroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Haryana   2001 Total Rape Victims                      398
#                Victims of Incest Rape                    0
#                Victims of Other Rape                   398
#           2002 Total Rape Victims                      361
#                Victims of Incest Rape                   52
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Haryana   2001 Total Rape Victims                         3
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      3
#           2002 Total Rape Victims                         1
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Haryana   2001 Total Rape Victims                             62
# ...

# %%
sumha=pd.DataFrame(Haryanagroup.sum(axis=0))
sumha
sumha.columns=['Haryana']
Haryanagroup.sum(axis=0)
#major victims are around 18-30 yrs and are followed by 14-18 yrs 1476 victims and 30-50 yrs 1262 victims
# Out:
# Rape_Cases_Reported          10018
# Victims_Above_50_Yrs            62
# Victims_Between_10-14_Yrs      544
# Victims_Between_14-18_Yrs     1476
# Victims_Between_18-30_Yrs     6438
# Victims_Between_30-50_Yrs     1262
# Victims_of_Rape_Total        10018
# Victims_Upto_10_Yrs            236
# dtype: int64

# %%
Haryanagroup.sum(axis=1)
#The no of victims have been increased from 1194 in 2001 to 2160 in 2010
# Out:
# Area_Name  Year  Subgroup
# Haryana    2001  Total Rape Victims        1194
#                  Victims of Incest Rape       0
#                  Victims of Other Rape     1194
#            2002  Total Rape Victims        1083
#                  Victims of Incest Rape     156
#                  Victims of Other Rape      927
#            2003  Total Rape Victims        1059
#                  Victims of Incest Rape      42
#                  Victims of Other Rape     1017
#            2004  Total Rape Victims        1158
#                  Victims of Incest Rape      60
#                  Victims of Other Rape     1098
#            2005  Total Rape Victims        1383
#                  Victims of Incest Rape      45
#                  Victims of Other Rape     1338
#            2006  Total Rape Victims        1824
#                  Victims of Incest Rape      30
#                  Victims of Other Rape     1794
#            2007  Total Rape Victims        1464
# ...

# %% [markdown]
# Lakshadweep Analysis

# %%
Lakshadweep=df[(df['Area_Name']=='Lakshadweep')]
Lakshadweep.head()
# Out:
#        Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 540  Lakshadweep  2001      Total Rape Victims                    0
# 541  Lakshadweep  2001  Victims of Incest Rape                    0
# 542  Lakshadweep  2001   Victims of Other Rape                    0
# 543  Lakshadweep  2002      Total Rape Victims                    1
# 544  Lakshadweep  2002  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 540                     0                          0
# 541                     0                          0
# 542                     0                          0
# 543                     0                          0
# 544                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 540                          0                          0
# 541                          0                          0
# ...

# %%
Lakshadweepgroup=Lakshadweep.groupby(['Area_Name','Year','Subgroup']).mean()
Lakshadweepgroup.head()
# Out:
#                                          Rape_Cases_Reported  \
# Area_Name   Year Subgroup
# Lakshadweep 2001 Total Rape Victims                        0
#                  Victims of Incest Rape                    0
#                  Victims of Other Rape                     0
#             2002 Total Rape Victims                        1
#                  Victims of Incest Rape                    0
#
#                                          Victims_Above_50_Yrs  \
# Area_Name   Year Subgroup
# Lakshadweep 2001 Total Rape Victims                         0
#                  Victims of Incest Rape                     0
#                  Victims of Other Rape                      0
#             2002 Total Rape Victims                         0
#                  Victims of Incest Rape                     0
#
#                                          Victims_Between_10-14_Yrs  \
# Area_Name   Year Subgroup
# Lakshadweep 2001 Total Rape Victims                              0
# ...

# %%
sumlk=pd.DataFrame(Lakshadweepgroup.sum(axis=0))
sumlk
sumlk.columns=['Lakshwadeep']
Lakshadweepgroup.sum(axis=0)
#Lashadweep has very less number of cases and victims are mostly from 18-30 yrs and rest are from 30-50 yrs
# Out:
# Rape_Cases_Reported          14
# Victims_Above_50_Yrs          0
# Victims_Between_10-14_Yrs     0
# Victims_Between_14-18_Yrs     0
# Victims_Between_18-30_Yrs    10
# Victims_Between_30-50_Yrs     4
# Victims_of_Rape_Total        14
# Victims_Upto_10_Yrs           0
# dtype: int64

# %%
Lakshadweepgroup.sum(axis=1)
#Few years there has been few cases reported in few there has been no rape cases reported
# Out:
# Area_Name    Year  Subgroup
# Lakshadweep  2001  Total Rape Victims        0
#                    Victims of Incest Rape    0
#                    Victims of Other Rape     0
#              2002  Total Rape Victims        3
#                    Victims of Incest Rape    0
#                    Victims of Other Rape     3
#              2003  Total Rape Victims        6
#                    Victims of Incest Rape    0
#                    Victims of Other Rape     6
#              2004  Total Rape Victims        0
#                    Victims of Incest Rape    0
#                    Victims of Other Rape     0
#              2005  Total Rape Victims        0
#                    Victims of Incest Rape    0
#                    Victims of Other Rape     0
#              2006  Total Rape Victims        0
#                    Victims of Incest Rape    0
#                    Victims of Other Rape     0
#              2007  Total Rape Victims        3
# ...

# %% [markdown]
# Meghalaya Analysis

# %%
Meghalaya=df[(df['Area_Name']=='Meghalaya')]
Meghalaya.head()
# Out:
#      Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 660  Meghalaya  2001      Total Rape Victims                   26
# 661  Meghalaya  2001  Victims of Incest Rape                    5
# 662  Meghalaya  2001   Victims of Other Rape                   21
# 663  Meghalaya  2002      Total Rape Victims                   38
# 664  Meghalaya  2002  Victims of Incest Rape                    1
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 660                     0                          2
# 661                     0                          0
# 662                     0                          2
# 663                     0                          9
# 664                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 660                          4                         14
# 661                          1                          1
# 662                          3                         13
# ...

# %%
Meghalayagroup=Meghalaya.groupby(['Area_Name','Year','Subgroup']).mean()
Meghalayagroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Meghalaya 2001 Total Rape Victims                       26
#                Victims of Incest Rape                    5
#                Victims of Other Rape                    21
#           2002 Total Rape Victims                       38
#                Victims of Incest Rape                    1
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Meghalaya 2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Meghalaya 2001 Total Rape Victims                              2
# ...

# %%
summg=pd.DataFrame(Meghalayagroup.sum(axis=0))
summg
summg.columns=['Meghalaya']
Meghalayagroup.sum(axis=0)
#Though majority of victims are in age 18-30 yrs, there are significant no of victims under 10-14, 14-18 and under 10 yrs as well
# Out:
# Rape_Cases_Reported          1452
# Victims_Above_50_Yrs            8
# Victims_Between_10-14_Yrs     262
# Victims_Between_14-18_Yrs     366
# Victims_Between_18-30_Yrs     524
# Victims_Between_30-50_Yrs      82
# Victims_of_Rape_Total        1478
# Victims_Upto_10_Yrs           236
# dtype: int64

# %%
Meghalayagroup.sum(axis=1)
#There has been more no of Incest rape reported in the region consistently over the decade.
#The no of cases have also increased from 78 to 451
# Out:
# Area_Name  Year  Subgroup
# Meghalaya  2001  Total Rape Victims         78
#                  Victims of Incest Rape     15
#                  Victims of Other Rape      63
#            2002  Total Rape Victims        114
#                  Victims of Incest Rape      3
#                  Victims of Other Rape     111
#            2003  Total Rape Victims        120
#                  Victims of Incest Rape     15
#                  Victims of Other Rape     105
#            2004  Total Rape Victims        162
#                  Victims of Incest Rape     12
#                  Victims of Other Rape     150
#            2005  Total Rape Victims        189
#                  Victims of Incest Rape     12
#                  Victims of Other Rape     177
#            2006  Total Rape Victims        222
#                  Victims of Incest Rape      0
#                  Victims of Other Rape     222
#            2007  Total Rape Victims        268
# ...

# %% [markdown]
# Madhya Pradesh Analysis

# %%
MP=df[(df['Area_Name']=='Madhya Pradesh')]
MP.head()
# Out:
#           Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 570  Madhya Pradesh  2001      Total Rape Victims                 2851
# 571  Madhya Pradesh  2001  Victims of Incest Rape                  301
# 572  Madhya Pradesh  2001   Victims of Other Rape                 2550
# 573  Madhya Pradesh  2002      Total Rape Victims                 2891
# 574  Madhya Pradesh  2002  Victims of Incest Rape                   72
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 570                    27                        304
# 571                     0                         39
# 572                    27                        265
# 573                    14                        185
# 574                     1                         11
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 570                        557                       1250
# 571                         66                        130
# ...

# %%
MPgroup=MP.groupby(['Area_Name','Year','Subgroup']).mean()
MPgroup.head()
# Out:
#                                             Rape_Cases_Reported  \
# Area_Name      Year Subgroup
# Madhya Pradesh 2001 Total Rape Victims                     2851
#                     Victims of Incest Rape                  301
#                     Victims of Other Rape                  2550
#                2002 Total Rape Victims                     2891
#                     Victims of Incest Rape                   72
#
#                                             Victims_Above_50_Yrs  \
# Area_Name      Year Subgroup
# Madhya Pradesh 2001 Total Rape Victims                        27
#                     Victims of Incest Rape                     0
#                     Victims of Other Rape                     27
#                2002 Total Rape Victims                        14
#                     Victims of Incest Rape                     1
#
#                                             Victims_Between_10-14_Yrs  \
# Area_Name      Year Subgroup
# ...

# %%
sumMP=pd.DataFrame(MPgroup.sum(axis=0))
sumMP
sumMP.columns=['MadhyaPradesh']
MPgroup.sum(axis=0)
#The majority of victims are under 18-30, with significant nos are under 14-18 and 30-50 as well
# Out:
# Rape_Cases_Reported          58512
# Victims_Above_50_Yrs           362
# Victims_Between_10-14_Yrs     4998
# Victims_Between_14-18_Yrs    11108
# Victims_Between_18-30_Yrs    29064
# Victims_Between_30-50_Yrs    11566
# Victims_of_Rape_Total        58514
# Victims_Upto_10_Yrs           1416
# dtype: int64

# %%
MPgroup.sum(axis=1)
#The cases per year has been uniform around 8500-9000
# Out:
# Area_Name       Year  Subgroup
# Madhya Pradesh  2001  Total Rape Victims        8553
#                       Victims of Incest Rape     903
#                       Victims of Other Rape     7650
#                 2002  Total Rape Victims        8673
#                       Victims of Incest Rape     216
#                       Victims of Other Rape     8457
#                 2003  Total Rape Victims        8214
#                       Victims of Incest Rape     369
#                       Victims of Other Rape     7845
#                 2004  Total Rape Victims        8625
#                       Victims of Incest Rape     189
#                       Victims of Other Rape     8436
#                 2005  Total Rape Victims        8763
#                       Victims of Incest Rape     423
#                       Victims of Other Rape     8340
#                 2006  Total Rape Victims        8700
#                       Victims of Incest Rape      87
# ...

# %% [markdown]
# Punjab Analysis

# %%
Punjab=df[(df['Area_Name']=='Punjab')]
Punjab.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 810    Punjab  2001      Total Rape Victims                  298
# 811    Punjab  2001  Victims of Incest Rape                    0
# 812    Punjab  2001   Victims of Other Rape                  298
# 813    Punjab  2002      Total Rape Victims                  299
# 814    Punjab  2002  Victims of Incest Rape                    4
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 810                     1                         30
# 811                     0                          0
# 812                     1                         30
# 813                     1                         12
# 814                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 810                        137                         98
# 811                          0                          0
# 812                        137                         98
# ...

# %%
Punjabgroup=Punjab.groupby(['Area_Name','Year','Subgroup']).mean()
Punjabgroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Punjab    2001 Total Rape Victims                      298
#                Victims of Incest Rape                    0
#                Victims of Other Rape                   298
#           2002 Total Rape Victims                      299
#                Victims of Incest Rape                    4
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Punjab    2001 Total Rape Victims                         1
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      1
#           2002 Total Rape Victims                         1
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Punjab    2001 Total Rape Victims                             30
# ...

# %%
sumPn=pd.DataFrame(Punjabgroup.sum(axis=0))
sumPn
sumPn.columns=['Punjab']
Punjabgroup.sum(axis=0)
#The majority of victims are under 18-30, with significant nos are under 14-18 and 30-50 as well
# Out:
# Rape_Cases_Reported          8600
# Victims_Above_50_Yrs           26
# Victims_Between_10-14_Yrs     534
# Victims_Between_14-18_Yrs    1234
# Victims_Between_18-30_Yrs    5316
# Victims_Between_30-50_Yrs    1180
# Victims_of_Rape_Total        8614
# Victims_Upto_10_Yrs           324
# dtype: int64

# %%
Punjabgroup.sum(axis=1)
#The no of cases has increased from 894 in 2001 to 1640 in 2010
# Out:
# Area_Name  Year  Subgroup
# Punjab     2001  Total Rape Victims         894
#                  Victims of Incest Rape       0
#                  Victims of Other Rape      894
#            2002  Total Rape Victims         897
#                  Victims of Incest Rape      12
#                  Victims of Other Rape      885
#            2003  Total Rape Victims        1140
#                  Victims of Incest Rape      27
#                  Victims of Other Rape     1113
#            2004  Total Rape Victims        1170
#                  Victims of Incest Rape     195
#                  Victims of Other Rape      975
#            2005  Total Rape Victims        1194
#                  Victims of Incest Rape     150
#                  Victims of Other Rape     1044
#            2006  Total Rape Victims        1326
#                  Victims of Incest Rape       3
#                  Victims of Other Rape     1323
#            2007  Total Rape Victims        1557
# ...

# %% [markdown]
# Odhisha Analysis

# %%
Odisha=df[(df['Area_Name']=='Odisha')]
Odisha.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 750    Odisha  2001      Total Rape Victims                  790
# 751    Odisha  2001  Victims of Incest Rape                    4
# 752    Odisha  2001   Victims of Other Rape                  786
# 753    Odisha  2002      Total Rape Victims                  691
# 754    Odisha  2002  Victims of Incest Rape                    1
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 750                     0                          9
# 751                     0                          0
# 752                     0                          9
# 753                     0                          9
# 754                     0                          1
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 750                        297                        402
# 751                          3                          1
# 752                        294                        401
# ...

# %%
Odishagroup=Odisha.groupby(['Area_Name','Year','Subgroup']).mean()
Odishagroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Odisha    2001 Total Rape Victims                      790
#                Victims of Incest Rape                    4
#                Victims of Other Rape                   786
#           2002 Total Rape Victims                      691
#                Victims of Incest Rape                    1
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Odisha    2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Odisha    2001 Total Rape Victims                              9
# ...

# %%
sumOd=pd.DataFrame(Odishagroup.sum(axis=0))
sumOd
sumOd.columns=['Odisha']
Odishagroup.sum(axis=0)
#the majority of the cases are in the age group of 18-30 followed by 30-50.
# Out:
# Rape_Cases_Reported          17720
# Victims_Above_50_Yrs            60
# Victims_Between_10-14_Yrs      396
# Victims_Between_14-18_Yrs     1070
# Victims_Between_18-30_Yrs    12844
# Victims_Between_30-50_Yrs     3074
# Victims_of_Rape_Total        17720
# Victims_Upto_10_Yrs            276
# dtype: int64

# %%
Odishagroup.sum(axis=1)
#The no of incest rape has increased in 2010 to 111
# Out:
# Area_Name  Year  Subgroup
# Odisha     2001  Total Rape Victims        2370
#                  Victims of Incest Rape      12
#                  Victims of Other Rape     2358
#            2002  Total Rape Victims        2073
#                  Victims of Incest Rape       3
#                  Victims of Other Rape     2070
#            2003  Total Rape Victims        2175
#                  Victims of Incest Rape       0
#                  Victims of Other Rape     2175
#            2004  Total Rape Victims        2310
#                  Victims of Incest Rape       3
#                  Victims of Other Rape     2307
#            2005  Total Rape Victims        2397
#                  Victims of Incest Rape      21
#                  Victims of Other Rape     2376
#            2006  Total Rape Victims        2955
#                  Victims of Incest Rape       0
#                  Victims of Other Rape     2955
#            2007  Total Rape Victims        2817
# ...

# %% [markdown]
# Gujarat Analysis

# %%
Gujarat=df[(df['Area_Name']=='Gujarat')]
Gujarat.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 330   Gujarat  2001      Total Rape Victims                  286
# 331   Gujarat  2001  Victims of Incest Rape                    2
# 332   Gujarat  2001   Victims of Other Rape                  284
# 333   Gujarat  2002      Total Rape Victims                  267
# 334   Gujarat  2002  Victims of Incest Rape                   10
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 330                     0                         23
# 331                     0                          0
# 332                     0                         23
# 333                     0                         16
# 334                     0                          4
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 330                         87                        125
# 331                          2                          0
# 332                         85                        125
# ...

# %%
Gujaratgroup=Gujarat.groupby(['Area_Name','Year','Subgroup']).mean()
Gujaratgroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Gujarat   2001 Total Rape Victims                      286
#                Victims of Incest Rape                    2
#                Victims of Other Rape                   284
#           2002 Total Rape Victims                      267
#                Victims of Incest Rape                   10
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Gujarat   2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Gujarat   2001 Total Rape Victims                             23
# ...

# %%
sumGuj=pd.DataFrame(Gujaratgroup.sum(axis=0))
sumGuj
sumGuj.columns=['Gujarat']
Gujaratgroup.sum(axis=0)
#Majority of victims are around 18-30 yrs
# Out:
# Rape_Cases_Reported          6674
# Victims_Above_50_Yrs           16
# Victims_Between_10-14_Yrs     506
# Victims_Between_14-18_Yrs    1100
# Victims_Between_18-30_Yrs    4070
# Victims_Between_30-50_Yrs     650
# Victims_of_Rape_Total        6678
# Victims_Upto_10_Yrs           336
# dtype: int64

# %%
Gujaratgroup.sum(axis=1)
#Over the decade, the no of cases have increased from 858 to 1212
# Out:
# Area_Name  Year  Subgroup
# Gujarat    2001  Total Rape Victims         858
#                  Victims of Incest Rape       6
#                  Victims of Other Rape      852
#            2002  Total Rape Victims         803
#                  Victims of Incest Rape      30
#                  Victims of Other Rape      773
#            2003  Total Rape Victims         708
#                  Victims of Incest Rape      21
#                  Victims of Other Rape      687
#            2004  Total Rape Victims        1017
#                  Victims of Incest Rape      42
#                  Victims of Other Rape      975
#            2005  Total Rape Victims         972
#                  Victims of Incest Rape      57
#                  Victims of Other Rape      915
#            2006  Total Rape Victims        1062
#                  Victims of Incest Rape      48
#                  Victims of Other Rape     1014
#            2007  Total Rape Victims         950
# ...

# %% [markdown]
# UP Analysis

# %%
UP=df[(df['Area_Name']=='Uttar Pradesh')]
UP.head()
# Out:
#          Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 960  Uttar Pradesh  2001      Total Rape Victims                 1958
# 961  Uttar Pradesh  2001  Victims of Incest Rape                    3
# 962  Uttar Pradesh  2001   Victims of Other Rape                 1955
# 963  Uttar Pradesh  2002      Total Rape Victims                 1415
# 964  Uttar Pradesh  2002  Victims of Incest Rape                   12
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 960                     0                        122
# 961                     0                          2
# 962                     0                        120
# 963                     0                        111
# 964                     0                          1
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 960                        406                       1082
# 961                          0                          1
# ...

# %%
UPgroup=UP.groupby(['Area_Name','Year','Subgroup']).mean()
UPgroup.head()
# Out:
#                                            Rape_Cases_Reported  \
# Area_Name     Year Subgroup
# Uttar Pradesh 2001 Total Rape Victims                     1958
#                    Victims of Incest Rape                    3
#                    Victims of Other Rape                  1955
#               2002 Total Rape Victims                     1415
#                    Victims of Incest Rape                   12
#
#                                            Victims_Above_50_Yrs  \
# Area_Name     Year Subgroup
# Uttar Pradesh 2001 Total Rape Victims                         0
#                    Victims of Incest Rape                     0
#                    Victims of Other Rape                      0
#               2002 Total Rape Victims                         0
#                    Victims of Incest Rape                     0
#
#                                            Victims_Between_10-14_Yrs  \
# Area_Name     Year Subgroup
# ...

# %%
sumUP=pd.DataFrame(UPgroup.sum(axis=0))
sumUP
sumUP.columns=['UP']
UPgroup.sum(axis=0)
#majority victims are between 18-30, there are significant no of victims in 10-14 yrs and 14-18 yrs as well
# Out:
# Rape_Cases_Reported          30106
# Victims_Above_50_Yrs            24
# Victims_Between_10-14_Yrs     2848
# Victims_Between_14-18_Yrs     6184
# Victims_Between_18-30_Yrs    16152
# Victims_Between_30-50_Yrs     4172
# Victims_of_Rape_Total        30106
# Victims_Upto_10_Yrs            726
# dtype: int64

# %%
UPgroup.sum(axis=1)
# Out:
# Area_Name      Year  Subgroup
# Uttar Pradesh  2001  Total Rape Victims        5874
#                      Victims of Incest Rape       9
#                      Victims of Other Rape     5865
#                2002  Total Rape Victims        4245
#                      Victims of Incest Rape      36
#                      Victims of Other Rape     4209
#                2003  Total Rape Victims        2733
#                      Victims of Incest Rape      30
#                      Victims of Other Rape     2703
#                2004  Total Rape Victims        4191
#                      Victims of Incest Rape     105
#                      Victims of Other Rape     4086
#                2005  Total Rape Victims        3651
#                      Victims of Incest Rape     210
#                      Victims of Other Rape     3441
#                2006  Total Rape Victims        3942
#                      Victims of Incest Rape       0
# ...

# %% [markdown]
# Mizoram Analysis

# %%
Mizoram=df[(df['Area_Name']=='Mizoram')]
Mizoram.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 690   Mizoram  2001      Total Rape Victims                   52
# 691   Mizoram  2001  Victims of Incest Rape                    0
# 692   Mizoram  2001   Victims of Other Rape                   52
# 693   Mizoram  2002      Total Rape Victims                   76
# 694   Mizoram  2002  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 690                     0                          0
# 691                     0                          0
# 692                     0                          0
# 693                     9                          1
# 694                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 690                         30                         14
# 691                          0                          0
# 692                         30                         14
# ...

# %%
Mizoramgroup=Mizoram.groupby(['Area_Name','Year','Subgroup']).mean()
Mizoramgroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Mizoram   2001 Total Rape Victims                       52
#                Victims of Incest Rape                    0
#                Victims of Other Rape                    52
#           2002 Total Rape Victims                       76
#                Victims of Incest Rape                    0
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Mizoram   2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         9
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Mizoram   2001 Total Rape Victims                              0
# ...

# %%
sumMz=pd.DataFrame(Mizoramgroup.sum(axis=0))
sumMz
sumMz.columns=['Mizoram']
Mizoramgroup.sum(axis=0)
#Major victims are under the age group 18-30 yrs and there are significant no of victims under 10 yrs as well
# Out:
# Rape_Cases_Reported          1292
# Victims_Above_50_Yrs           30
# Victims_Between_10-14_Yrs     140
# Victims_Between_14-18_Yrs     234
# Victims_Between_18-30_Yrs     538
# Victims_Between_30-50_Yrs     240
# Victims_of_Rape_Total        1292
# Victims_Upto_10_Yrs           110
# dtype: int64

# %%
Mizoramgroup.sum(axis=1)
#The cases have increased from 156 in 2001 to 276 in 2010
# Out:
# Area_Name  Year  Subgroup
# Mizoram    2001  Total Rape Victims        156
#                  Victims of Incest Rape      0
#                  Victims of Other Rape     156
#            2002  Total Rape Victims        228
#                  Victims of Incest Rape      0
#                  Victims of Other Rape     228
#            2003  Total Rape Victims        162
#                  Victims of Incest Rape      6
#                  Victims of Other Rape     156
#            2004  Total Rape Victims         60
#                  Victims of Incest Rape      0
#                  Victims of Other Rape      60
#            2005  Total Rape Victims        111
#                  Victims of Incest Rape      0
#                  Victims of Other Rape     111
#            2006  Total Rape Victims        216
#                  Victims of Incest Rape      0
#                  Victims of Other Rape     216
#            2007  Total Rape Victims        249
# ...

# %% [markdown]
# Andhra Pradesh Analysis

# %%
AP=df[(df['Area_Name']=='Andhra Pradesh')]
AP.head()
# Out:
#          Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 30  Andhra Pradesh  2001      Total Rape Victims                  871
# 31  Andhra Pradesh  2001  Victims of Incest Rape                    4
# 32  Andhra Pradesh  2001   Victims of Other Rape                  867
# 33  Andhra Pradesh  2002      Total Rape Victims                 1002
# 34  Andhra Pradesh  2002  Victims of Incest Rape                    5
#
#     Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 30                    14                        138
# 31                     0                          2
# 32                    14                        136
# 33                     8                         67
# 34                     0                          2
#
#     Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 30                        254                        328
# 31                          0                          2
# ...

# %%
APgroup=AP.groupby(['Area_Name','Year','Subgroup']).mean()
APgroup.head()
# Out:
#                                             Rape_Cases_Reported  \
# Area_Name      Year Subgroup
# Andhra Pradesh 2001 Total Rape Victims                      871
#                     Victims of Incest Rape                    4
#                     Victims of Other Rape                   867
#                2002 Total Rape Victims                     1002
#                     Victims of Incest Rape                    5
#
#                                             Victims_Above_50_Yrs  \
# Area_Name      Year Subgroup
# Andhra Pradesh 2001 Total Rape Victims                        14
#                     Victims of Incest Rape                     0
#                     Victims of Other Rape                     14
#                2002 Total Rape Victims                         8
#                     Victims of Incest Rape                     0
#
#                                             Victims_Between_10-14_Yrs  \
# Area_Name      Year Subgroup
# ...

# %%
sumAP=pd.DataFrame(APgroup.sum(axis=0))
sumAP
sumAP.columns=['AndhraPradesh']
APgroup.sum(axis=0)
#Major victims are under the age group 18-30 yrs and there are significant no of victims between 10-14 yrs and 14-18 yrs as well
# Out:
# Rape_Cases_Reported          21392
# Victims_Above_50_Yrs           198
# Victims_Between_10-14_Yrs     2510
# Victims_Between_14-18_Yrs     4022
# Victims_Between_18-30_Yrs    11262
# Victims_Between_30-50_Yrs     2540
# Victims_of_Rape_Total        21392
# Victims_Upto_10_Yrs            860
# dtype: int64

# %%
APgroup.sum(axis=1)
#The no of cases have increased from 2613 in 2001 to 4086 in 2010
# Out:
# Area_Name       Year  Subgroup
# Andhra Pradesh  2001  Total Rape Victims        2613
#                       Victims of Incest Rape      12
#                       Victims of Other Rape     2601
#                 2002  Total Rape Victims        3006
#                       Victims of Incest Rape      15
#                       Victims of Other Rape     2991
#                 2003  Total Rape Victims        2838
#                       Victims of Incest Rape      45
#                       Victims of Other Rape     2793
#                 2004  Total Rape Victims        3048
#                       Victims of Incest Rape      15
#                       Victims of Other Rape     3033
#                 2005  Total Rape Victims        2805
#                       Victims of Incest Rape      54
#                       Victims of Other Rape     2751
#                 2006  Total Rape Victims        3147
#                       Victims of Incest Rape       3
# ...

# %% [markdown]
# Rajasthan Analysis

# %%
Rajasthan=df[(df['Area_Name']=='Rajasthan')]
Rajasthan.head()
# Out:
#      Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 840  Rajasthan  2001      Total Rape Victims                 1049
# 841  Rajasthan  2001  Victims of Incest Rape                   18
# 842  Rajasthan  2001   Victims of Other Rape                 1031
# 843  Rajasthan  2002      Total Rape Victims                 1051
# 844  Rajasthan  2002  Victims of Incest Rape                   31
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 840                     7                         44
# 841                     0                          1
# 842                     7                         43
# 843                     5                          8
# 844                     1                          3
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 840                        229                        606
# 841                          7                          8
# 842                        222                        598
# ...

# %%
Rajasthangroup=Rajasthan.groupby(['Area_Name','Year','Subgroup']).mean()
Rajasthangroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Rajasthan 2001 Total Rape Victims                     1049
#                Victims of Incest Rape                   18
#                Victims of Other Rape                  1031
#           2002 Total Rape Victims                     1051
#                Victims of Incest Rape                   31
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Rajasthan 2001 Total Rape Victims                         7
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      7
#           2002 Total Rape Victims                         5
#                Victims of Incest Rape                     1
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Rajasthan 2001 Total Rape Victims                             44
# ...

# %%
sumRaj=pd.DataFrame(Rajasthangroup.sum(axis=0))
sumRaj
sumRaj.columns=['Rajasthan']
Rajasthangroup.sum(axis=0)
#Major victims are under the age group 18-30 yrs followed by 30-50 yrs
# Out:
# Rape_Cases_Reported          23898
# Victims_Above_50_Yrs           210
# Victims_Between_10-14_Yrs     1100
# Victims_Between_14-18_Yrs     3750
# Victims_Between_18-30_Yrs    13732
# Victims_Between_30-50_Yrs     4660
# Victims_of_Rape_Total        23908
# Victims_Upto_10_Yrs            456
# dtype: int64

# %%
Rajasthangroup.sum(axis=1)
#the no of cases have increased from 3147 to 4717
# Out:
# Area_Name  Year  Subgroup
# Rajasthan  2001  Total Rape Victims        3147
#                  Victims of Incest Rape      54
#                  Victims of Other Rape     3093
#            2002  Total Rape Victims        3153
#                  Victims of Incest Rape      93
#                  Victims of Other Rape     3060
#            2003  Total Rape Victims        3150
#                  Victims of Incest Rape      96
#                  Victims of Other Rape     3054
#            2004  Total Rape Victims        3114
#                  Victims of Incest Rape     117
#                  Victims of Other Rape     2997
#            2005  Total Rape Victims        2979
#                  Victims of Incest Rape      99
#                  Victims of Other Rape     2880
#            2006  Total Rape Victims        3255
#                  Victims of Incest Rape     126
#                  Victims of Other Rape     3129
#            2007  Total Rape Victims        3718
# ...

# %% [markdown]
# Daman & Diu Analysis

# %%
DD=df[(df['Area_Name']=='Daman & Diu')]
DD.head()
# Out:
#        Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 240  Daman & Diu  2001      Total Rape Victims                    0
# 241  Daman & Diu  2001  Victims of Incest Rape                    0
# 242  Daman & Diu  2001   Victims of Other Rape                    0
# 243  Daman & Diu  2002      Total Rape Victims                    0
# 244  Daman & Diu  2002  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 240                     0                          0
# 241                     0                          0
# 242                     0                          0
# 243                     0                          0
# 244                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 240                          0                          0
# 241                          0                          0
# ...

# %%
DDgroup=DD.groupby(['Area_Name','Year','Subgroup']).mean()
DDgroup.head()
# Out:
#                                          Rape_Cases_Reported  \
# Area_Name   Year Subgroup
# Daman & Diu 2001 Total Rape Victims                        0
#                  Victims of Incest Rape                    0
#                  Victims of Other Rape                     0
#             2002 Total Rape Victims                        0
#                  Victims of Incest Rape                    0
#
#                                          Victims_Above_50_Yrs  \
# Area_Name   Year Subgroup
# Daman & Diu 2001 Total Rape Victims                         0
#                  Victims of Incest Rape                     0
#                  Victims of Other Rape                      0
#             2002 Total Rape Victims                         0
#                  Victims of Incest Rape                     0
#
#                                          Victims_Between_10-14_Yrs  \
# Area_Name   Year Subgroup
# Daman & Diu 2001 Total Rape Victims                              0
# ...

# %%
sumDD=pd.DataFrame(DDgroup.sum(axis=0))
sumDD
sumDD.columns=['Daman&Diu']
DDgroup.sum(axis=0)
#Daman & Diu have least cases and majority of them come from the age bracket 14-18 yrs
# Out:
# Rape_Cases_Reported          28
# Victims_Above_50_Yrs          0
# Victims_Between_10-14_Yrs     2
# Victims_Between_14-18_Yrs     8
# Victims_Between_18-30_Yrs     6
# Victims_Between_30-50_Yrs     2
# Victims_of_Rape_Total        28
# Victims_Upto_10_Yrs          10
# dtype: int64

# %%
DDgroup.sum(axis=1)
#2003 had major case of 15 nos, followed by 2006 - 9, 2005 - 6
# Out:
# Area_Name    Year  Subgroup
# Daman & Diu  2001  Total Rape Victims         0
#                    Victims of Incest Rape     0
#                    Victims of Other Rape      0
#              2002  Total Rape Victims         0
#                    Victims of Incest Rape     0
#                    Victims of Other Rape      0
#              2003  Total Rape Victims        15
#                    Victims of Incest Rape     0
#                    Victims of Other Rape     15
#              2004  Total Rape Victims         3
#                    Victims of Incest Rape     0
#                    Victims of Other Rape      3
#              2005  Total Rape Victims         6
#                    Victims of Incest Rape     0
#                    Victims of Other Rape      6
#              2006  Total Rape Victims         9
#                    Victims of Incest Rape     0
#                    Victims of Other Rape      9
#              2007  Total Rape Victims         3
# ...

# %% [markdown]
# Maharashtra Analysis

# %%
Maharashtra=df[(df['Area_Name']=='Maharashtra')]
Maharashtra.head()
# Out:
#        Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 600  Maharashtra  2001      Total Rape Victims                 1302
# 601  Maharashtra  2001  Victims of Incest Rape                   20
# 602  Maharashtra  2001   Victims of Other Rape                 1282
# 603  Maharashtra  2002      Total Rape Victims                 1352
# 604  Maharashtra  2002  Victims of Incest Rape                   21
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 600                     4                        152
# 601                     0                          5
# 602                     4                        147
# 603                     7                        130
# 604                     0                          3
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 600                        419                        503
# 601                          6                          4
# ...

# %%
Maharashtragroup=Maharashtra.groupby(['Area_Name','Year','Subgroup']).mean()
Maharashtragroup.head()
# Out:
#                                          Rape_Cases_Reported  \
# Area_Name   Year Subgroup
# Maharashtra 2001 Total Rape Victims                     1302
#                  Victims of Incest Rape                   20
#                  Victims of Other Rape                  1282
#             2002 Total Rape Victims                     1352
#                  Victims of Incest Rape                   21
#
#                                          Victims_Above_50_Yrs  \
# Area_Name   Year Subgroup
# Maharashtra 2001 Total Rape Victims                         4
#                  Victims of Incest Rape                     0
#                  Victims of Other Rape                      4
#             2002 Total Rape Victims                         7
#                  Victims of Incest Rape                     0
#
#                                          Victims_Between_10-14_Yrs  \
# Area_Name   Year Subgroup
# Maharashtra 2001 Total Rape Victims                            152
# ...

# %%
summh=pd.DataFrame(Maharashtragroup.sum(axis=0))
summh
summh.columns=['Mahasthra']
Maharashtragroup.sum(axis=0)
#Major victims are under the age group 18-30 yrs and there are significant no of victims in the group of 14-18 and 10-14 yrs as well
# Out:
# Rape_Cases_Reported          28892
# Victims_Above_50_Yrs           126
# Victims_Between_10-14_Yrs     2610
# Victims_Between_14-18_Yrs     8304
# Victims_Between_18-30_Yrs    13120
# Victims_Between_30-50_Yrs     2970
# Victims_of_Rape_Total        29010
# Victims_Upto_10_Yrs           1880
# dtype: int64

# %%
Maharashtragroup.sum(axis=1)
#The rape cases have increased from 3906 in 2001 to 4821 in 2010
# Out:
# Area_Name    Year  Subgroup
# Maharashtra  2001  Total Rape Victims        3906
#                    Victims of Incest Rape      60
#                    Victims of Other Rape     3846
#              2002  Total Rape Victims        4056
#                    Victims of Incest Rape      63
#                    Victims of Other Rape     3993
#              2003  Total Rape Victims        3820
#                    Victims of Incest Rape      56
#                    Victims of Other Rape     3764
#              2004  Total Rape Victims        4172
#                    Victims of Incest Rape      95
#                    Victims of Other Rape     4077
#              2005  Total Rape Victims        4643
#                    Victims of Incest Rape     114
#                    Victims of Other Rape     4529
#              2006  Total Rape Victims        4512
#                    Victims of Incest Rape     108
#                    Victims of Other Rape     4404
# ...

# %% [markdown]
# Tamil Nadu Analysis

# %%
TN=df[(df['Area_Name']=='Tamil Nadu')]
TN.head()
# Out:
#       Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 900  Tamil Nadu  2001      Total Rape Victims                  423
# 901  Tamil Nadu  2001  Victims of Incest Rape                   21
# 902  Tamil Nadu  2001   Victims of Other Rape                  402
# 903  Tamil Nadu  2002      Total Rape Victims                  534
# 904  Tamil Nadu  2002  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 900                     2                         15
# 901                     0                          2
# 902                     2                         13
# 903                     1                          8
# 904                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 900                        174                        192
# 901                          4                         13
# 902                        170                        179
# ...

# %%
TNgroup=TN.groupby(['Area_Name','Year','Subgroup']).mean()
TNgroup.head()
# Out:
#                                         Rape_Cases_Reported  \
# Area_Name  Year Subgroup
# Tamil Nadu 2001 Total Rape Victims                      423
#                 Victims of Incest Rape                   21
#                 Victims of Other Rape                   402
#            2002 Total Rape Victims                      534
#                 Victims of Incest Rape                    0
#
#                                         Victims_Above_50_Yrs  \
# Area_Name  Year Subgroup
# Tamil Nadu 2001 Total Rape Victims                         2
#                 Victims of Incest Rape                     0
#                 Victims of Other Rape                      2
#            2002 Total Rape Victims                         1
#                 Victims of Incest Rape                     0
#
#                                         Victims_Between_10-14_Yrs  \
# Area_Name  Year Subgroup
# Tamil Nadu 2001 Total Rape Victims                             15
# ...

# %%
sumTN=pd.DataFrame(TNgroup.sum(axis=0))
sumTN
sumTN.columns=['TamilNadu']
TNgroup.sum(axis=0)

#Major victims are under the age group 18-30 yrs and there are significant no of victims in the group of 14-18
# Out:
# Rape_Cases_Reported          11076
# Victims_Above_50_Yrs            24
# Victims_Between_10-14_Yrs      606
# Victims_Between_14-18_Yrs     1782
# Victims_Between_18-30_Yrs     7184
# Victims_Between_30-50_Yrs     1072
# Victims_of_Rape_Total        11098
# Victims_Upto_10_Yrs            430
# dtype: int64

# %%
TNgroup.sum(axis=1)
#The no of victims have increased from 1269 in 2001 to 2060 in 2010
# Out:
# Area_Name   Year  Subgroup
# Tamil Nadu  2001  Total Rape Victims        1269
#                   Victims of Incest Rape      63
#                   Victims of Other Rape     1206
#             2002  Total Rape Victims        1602
#                   Victims of Incest Rape       0
#                   Victims of Other Rape     1602
#             2003  Total Rape Victims        1671
#                   Victims of Incest Rape     120
#                   Victims of Other Rape     1551
#             2004  Total Rape Victims        1856
#                   Victims of Incest Rape     108
#                   Victims of Other Rape     1748
#             2005  Total Rape Victims        1713
#                   Victims of Incest Rape      33
#                   Victims of Other Rape     1680
#             2006  Total Rape Victims        1371
#                   Victims of Incest Rape       3
#                   Victims of Other Rape     1368
#             2007  Total Rape Victims        1587
# ...

# %% [markdown]
# Sikkim Analysis

# %%
Sikkim=df[(df['Area_Name']=='Sikkim')]
Sikkim.head()
# Out:
#     Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 870    Sikkim  2001      Total Rape Victims                    8
# 871    Sikkim  2001  Victims of Incest Rape                    1
# 872    Sikkim  2001   Victims of Other Rape                    7
# 873    Sikkim  2002      Total Rape Victims                    6
# 874    Sikkim  2002  Victims of Incest Rape                    1
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 870                     0                          0
# 871                     0                          0
# 872                     0                          0
# 873                     0                          2
# 874                     0                          1
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 870                          4                          2
# 871                          0                          0
# 872                          4                          2
# ...

# %%
Sikkimgroup=Sikkim.groupby(['Area_Name','Year','Subgroup']).mean()
Sikkimgroup.head()
# Out:
#                                        Rape_Cases_Reported  \
# Area_Name Year Subgroup
# Sikkim    2001 Total Rape Victims                        8
#                Victims of Incest Rape                    1
#                Victims of Other Rape                     7
#           2002 Total Rape Victims                        6
#                Victims of Incest Rape                    1
#
#                                        Victims_Above_50_Yrs  \
# Area_Name Year Subgroup
# Sikkim    2001 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#                Victims of Other Rape                      0
#           2002 Total Rape Victims                         0
#                Victims of Incest Rape                     0
#
#                                        Victims_Between_10-14_Yrs  \
# Area_Name Year Subgroup
# Sikkim    2001 Total Rape Victims                              0
# ...

# %%
sumsk=pd.DataFrame(Sikkimgroup.sum(axis=0))
sumsk
sumsk.columns=['Sikkim']
Sikkimgroup.sum(axis=0)
#Though the no of cases are relatively less, the major victims are minors ranging from below 10 till 18 yrs
# Out:
# Rape_Cases_Reported          290
# Victims_Above_50_Yrs           0
# Victims_Between_10-14_Yrs     68
# Victims_Between_14-18_Yrs     66
# Victims_Between_18-30_Yrs     52
# Victims_Between_30-50_Yrs     20
# Victims_of_Rape_Total        298
# Victims_Upto_10_Yrs           92
# dtype: int64

# %%
Sikkimgroup.sum(axis=1)
#cases have increased from 24 to 54
# Out:
# Area_Name  Year  Subgroup
# Sikkim     2001  Total Rape Victims        24
#                  Victims of Incest Rape     3
#                  Victims of Other Rape     21
#            2002  Total Rape Victims        18
#                  Victims of Incest Rape     3
#                  Victims of Other Rape     15
#            2003  Total Rape Victims        30
#                  Victims of Incest Rape     0
#                  Victims of Other Rape     30
#            2004  Total Rape Victims        11
#                  Victims of Incest Rape     0
#                  Victims of Other Rape     11
#            2005  Total Rape Victims        58
#                  Victims of Incest Rape     3
#                  Victims of Other Rape     55
#            2006  Total Rape Victims        60
#                  Victims of Incest Rape     0
#                  Victims of Other Rape     60
#            2007  Total Rape Victims        72
#                  Victims of Incest Rape    12
# ...

# %% [markdown]
# Chhattisgarh Analysis

# %%
Chhattisgarh=df[(df['Area_Name']=='Chhattisgarh')]
Chhattisgarh.head()
# Out:
#         Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 180  Chhattisgarh  2001      Total Rape Victims                  959
# 181  Chhattisgarh  2001  Victims of Incest Rape                    6
# 182  Chhattisgarh  2001   Victims of Other Rape                  953
# 183  Chhattisgarh  2002      Total Rape Victims                  992
# 184  Chhattisgarh  2002  Victims of Incest Rape                   63
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 180                     4                        191
# 181                     0                          3
# 182                     4                        188
# 183                    11                        131
# 184                     3                         13
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 180                        218                        384
# 181                          1                          1
# ...

# %%
Chhattisgarhgroup=Chhattisgarh.groupby(['Area_Name','Year','Subgroup']).mean()
Chhattisgarhgroup.head()
# Out:
#                                           Rape_Cases_Reported  \
# Area_Name    Year Subgroup
# Chhattisgarh 2001 Total Rape Victims                      959
#                   Victims of Incest Rape                    6
#                   Victims of Other Rape                   953
#              2002 Total Rape Victims                      992
#                   Victims of Incest Rape                   63
#
#                                           Victims_Above_50_Yrs  \
# Area_Name    Year Subgroup
# Chhattisgarh 2001 Total Rape Victims                         4
#                   Victims of Incest Rape                     0
#                   Victims of Other Rape                      4
#              2002 Total Rape Victims                        11
#                   Victims of Incest Rape                     3
#
#                                           Victims_Between_10-14_Yrs  \
# Area_Name    Year Subgroup
# ...

# %%
sumCt=pd.DataFrame(Chhattisgarhgroup.sum(axis=0))
sumCt
sumCt.columns=['Chhattisgarh']
Chhattisgarhgroup.sum(axis=0)
#Major victims are under the age group 18-30 yrs and there are significant no of victims in the group of 14-18 yrs and 30-50 yrs
# Out:
# Rape_Cases_Reported          19502
# Victims_Above_50_Yrs           226
# Victims_Between_10-14_Yrs     2414
# Victims_Between_14-18_Yrs     3986
# Victims_Between_18-30_Yrs     8678
# Victims_Between_30-50_Yrs     3608
# Victims_of_Rape_Total        19502
# Victims_Upto_10_Yrs            590
# dtype: int64

# %%
Chhattisgarhgroup.sum(axis=1)
# Out:
# Area_Name     Year  Subgroup
# Chhattisgarh  2001  Total Rape Victims        2877
#                     Victims of Incest Rape      18
#                     Victims of Other Rape     2859
#               2002  Total Rape Victims        2976
#                     Victims of Incest Rape     189
#                     Victims of Other Rape     2787
#               2003  Total Rape Victims        2694
#                     Victims of Incest Rape     117
#                     Victims of Other Rape     2577
#               2004  Total Rape Victims        2907
#                     Victims of Incest Rape     234
#                     Victims of Other Rape     2673
#               2005  Total Rape Victims        2970
#                     Victims of Incest Rape     330
#                     Victims of Other Rape     2640
#               2006  Total Rape Victims        2985
#                     Victims of Incest Rape     291
#                     Victims of Other Rape     2694
# ...

# %% [markdown]
# Puducherry Analysis

# %%
Puducherry=df[(df['Area_Name']=='Puducherry')]
Puducherry.head()
# Out:
#       Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 780  Puducherry  2001      Total Rape Victims                    9
# 781  Puducherry  2001  Victims of Incest Rape                    0
# 782  Puducherry  2001   Victims of Other Rape                    9
# 783  Puducherry  2002      Total Rape Victims                    6
# 784  Puducherry  2002  Victims of Incest Rape                    0
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 780                     0                          2
# 781                     0                          0
# 782                     0                          2
# 783                     0                          0
# 784                     0                          0
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 780                          2                          1
# 781                          0                          0
# 782                          2                          1
# ...

# %%
Puducherrygroup=Puducherry.groupby(['Area_Name','Year','Subgroup']).mean()
Puducherrygroup.head()
# Out:
#                                         Rape_Cases_Reported  \
# Area_Name  Year Subgroup
# Puducherry 2001 Total Rape Victims                        9
#                 Victims of Incest Rape                    0
#                 Victims of Other Rape                     9
#            2002 Total Rape Victims                        6
#                 Victims of Incest Rape                    0
#
#                                         Victims_Above_50_Yrs  \
# Area_Name  Year Subgroup
# Puducherry 2001 Total Rape Victims                         0
#                 Victims of Incest Rape                     0
#                 Victims of Other Rape                      0
#            2002 Total Rape Victims                         0
#                 Victims of Incest Rape                     0
#
#                                         Victims_Between_10-14_Yrs  \
# Area_Name  Year Subgroup
# Puducherry 2001 Total Rape Victims                              2
# ...

# %%
sumpd=pd.DataFrame(Puducherrygroup.sum(axis=0))
sumpd
sumpd.columns=['Puducherry']
Puducherrygroup.sum(axis=0)
#Major victims are under the age group 18-30 yrs and there are significant no of victims in the group of 30-50 yrs
# Out:
# Rape_Cases_Reported          114
# Victims_Above_50_Yrs           0
# Victims_Between_10-14_Yrs      8
# Victims_Between_14-18_Yrs     50
# Victims_Between_18-30_Yrs     34
# Victims_Between_30-50_Yrs      4
# Victims_of_Rape_Total        114
# Victims_Upto_10_Yrs           18
# dtype: int64

# %%
Puducherrygroup.sum(axis=1)
# Out:
# Area_Name   Year  Subgroup
# Puducherry  2001  Total Rape Victims        27
#                   Victims of Incest Rape     0
#                   Victims of Other Rape     27
#             2002  Total Rape Victims        18
#                   Victims of Incest Rape     0
#                   Victims of Other Rape     18
#             2003  Total Rape Victims         6
#                   Victims of Incest Rape     0
#                   Victims of Other Rape      6
#             2004  Total Rape Victims        12
#                   Victims of Incest Rape     0
#                   Victims of Other Rape     12
#             2005  Total Rape Victims        18
#                   Victims of Incest Rape     0
#                   Victims of Other Rape     18
#             2006  Total Rape Victims        27
#                   Victims of Incest Rape     0
#                   Victims of Other Rape     27
#             2007  Total Rape Victims        27
# ...

# %% [markdown]
# West Bengal Analysis

# %%
WB=df[(df['Area_Name']=='West Bengal')]
WB.head()
# Out:
#         Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 1020  West Bengal  2001      Total Rape Victims                  709
# 1021  West Bengal  2001  Victims of Incest Rape                    0
# 1022  West Bengal  2001   Victims of Other Rape                  709
# 1023  West Bengal  2002      Total Rape Victims                  759
# 1024  West Bengal  2002  Victims of Incest Rape                    0
#
#       Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 1020                     0                          3
# 1021                     0                          0
# 1022                     0                          3
# 1023                     0                          3
# 1024                     0                          0
#
#       Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 1020                          5                        594
# 1021                          0                          0
# ...

# %%
WBgroup=WB.groupby(['Area_Name','Year','Subgroup']).mean()
WBgroup.head()
# Out:
#                                          Rape_Cases_Reported  \
# Area_Name   Year Subgroup
# West Bengal 2001 Total Rape Victims                      709
#                  Victims of Incest Rape                    0
#                  Victims of Other Rape                   709
#             2002 Total Rape Victims                      759
#                  Victims of Incest Rape                    0
#
#                                          Victims_Above_50_Yrs  \
# Area_Name   Year Subgroup
# West Bengal 2001 Total Rape Victims                         0
#                  Victims of Incest Rape                     0
#                  Victims of Other Rape                      0
#             2002 Total Rape Victims                         0
#                  Victims of Incest Rape                     0
#
#                                          Victims_Between_10-14_Yrs  \
# Area_Name   Year Subgroup
# West Bengal 2001 Total Rape Victims                              3
# ...

# %%
sumWB=pd.DataFrame(WBgroup.sum(axis=0))
sumWB
sumWB.columns=['WestBengal']
WBgroup.sum(axis=0)
#Major victims are under the age group 18-30 yrs followed by 30-50 yrs
# Out:
# Rape_Cases_Reported          32756
# Victims_Above_50_Yrs            20
# Victims_Between_10-14_Yrs      312
# Victims_Between_14-18_Yrs      546
# Victims_Between_18-30_Yrs    25172
# Victims_Between_30-50_Yrs     6580
# Victims_of_Rape_Total        32756
# Victims_Upto_10_Yrs            126
# dtype: int64

# %%
WBgroup.sum(axis=1)
# Out:
# Area_Name    Year  Subgroup
# West Bengal  2001  Total Rape Victims        2127
#                    Victims of Incest Rape       0
#                    Victims of Other Rape     2127
#              2002  Total Rape Victims        2277
#                    Victims of Incest Rape       0
#                    Victims of Other Rape     2277
#              2003  Total Rape Victims        3006
#                    Victims of Incest Rape      45
#                    Victims of Other Rape     2961
#              2004  Total Rape Victims        4425
#                    Victims of Incest Rape      72
#                    Victims of Other Rape     4353
#              2005  Total Rape Victims        5058
#                    Victims of Incest Rape     108
#                    Victims of Other Rape     4950
#              2006  Total Rape Victims        5193
#                    Victims of Incest Rape      18
#                    Victims of Other Rape     5175
# ...

# %% [markdown]
# sum of all the cases and victims categorisation is put into two dataframes for easy analysis further

# %%
df1=suma.join([sumt,sumk,sumb,sumc,sumde,sumas,sumuk,sumda,sumHP,sumJK,sumke,sumjk,sumGoa,sumARP,summn,sumha,sumlk])
df1
# Out:
#                            Andaman & Nicobar  Tripura  Karnataka  Bihar  \
# Rape_Cases_Reported                      168     3248       7834  22526
# Victims_Above_50_Yrs                       0        2         68     78
# Victims_Between_10-14_Yrs                 16      220        632    204
# Victims_Between_14-18_Yrs                 88      590        770   1000
# Victims_Between_18-30_Yrs                 42     2002       5014  16988
# Victims_Between_30-50_Yrs                  8      322        976   4194
# Victims_of_Rape_Total                    168     3252       7834  22526
# Victims_Upto_10_Yrs                       14      116        374     62
#
#                            Chandigarh  Delhi  Assam  Uttarakhand  \
# Rape_Cases_Reported               454  10292  25524         2202
# Victims_Above_50_Yrs                0     26    190            0
# Victims_Between_10-14_Yrs          92   1764    306          100
# ...

# %% [markdown]
# Observations
#
# Bihar, Assam, Delhi, Kerala, Jharkand and Haryana have crossed more than 10k cases.
# Dadra & Nagar Haveli. Lashwadeep, Andaman & Nicobar have less cases.

# %%
df2=summg.join([sumMP,sumPn,sumOd,sumGuj,sumUP,sumMz,sumAP,sumRaj,sumDD,summh,sumTN,sumsk,sumCt,sumna,sumpd,sumWB])
df2
# Out:
#                            Meghalaya  MadhyaPradesh  Punjab  Odisha  Gujarat  \
# Rape_Cases_Reported             1452          58512    8600   17720     6674
# Victims_Above_50_Yrs               8            362      26      60       16
# Victims_Between_10-14_Yrs        262           4998     534     396      506
# Victims_Between_14-18_Yrs        366          11108    1234    1070     1100
# Victims_Between_18-30_Yrs        524          29064    5316   12844     4070
# Victims_Between_30-50_Yrs         82          11566    1180    3074      650
# Victims_of_Rape_Total           1478          58514    8614   17720     6678
# Victims_Upto_10_Yrs              236           1416     324     276      336
#
#                               UP  Mizoram  AndhraPradesh  Rajasthan  \
# Rape_Cases_Reported        30106     1292          21392      23898
# Victims_Above_50_Yrs          24       30            198        210
# Victims_Between_10-14_Yrs   2848      140           2510       1100
# ...

# %% [markdown]
# Observations:
#
# Uttar Pradesh, Madhya Pradesh, Maharashtra, Tamil Nadu, Chattisgarh, West Bengal, Andhra Pradesh and Odisha have high no of cases.
# Daman & Diu, Nagaland, Puducherry, Sikkim have less no of cases

# %% [markdown]
# Statistical Analysis

# %%
df.describe()
# Out:
#              Year  Rape_Cases_Reported  Victims_Above_50_Yrs  \
# count  1050.00000          1050.000000           1050.000000
# mean   2005.50000           361.920000              1.866667
# std       2.87365           592.180572              4.640286
# min    2001.00000             0.000000              0.000000
# 25%    2003.00000             4.000000              0.000000
# 50%    2005.50000            37.000000              0.000000
# 75%    2008.00000           527.500000              1.000000
# max    2010.00000          3135.000000             43.000000
#
#        Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# count                1050.000000                1050.000000
# mean                   23.657143                  53.085714
# std                    50.677418                 115.127899
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# ...

# %% [markdown]
# Correlation Analysis

# %%
sns.heatmap(df.corr())

# %%
df.corr()
# Out:
#                                Year  Rape_Cases_Reported  \
# Year                       1.000000             0.070944
# Rape_Cases_Reported        0.070944             1.000000
# Victims_Above_50_Yrs       0.095368             0.652470
# Victims_Between_10-14_Yrs  0.057081             0.762842
# Victims_Between_14-18_Yrs  0.060579             0.780262
# Victims_Between_18-30_Yrs  0.069109             0.966432
# Victims_Between_30-50_Yrs  0.053460             0.925609
# Victims_of_Rape_Total      0.071121             0.999998
# Victims_Upto_10_Yrs        0.066608             0.665398
#
#                            Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# Year                                   0.095368                   0.057081
# Rape_Cases_Reported                    0.652470                   0.762842
# Victims_Above_50_Yrs                   1.000000                   0.595057
# Victims_Between_10-14_Yrs              0.595057                   1.000000
# ...

# %%
#certain columns are showing high correlation with each other
#Ex:- cases report and Victims_Between_18-30_Yrs have highest correlation followed by Victims_Between_30-50_Yrs

# %% [markdown]
# Relationship Analysis

# %%
sns.regplot(x='Rape_Cases_Reported',y='Victims_Between_18-30_Yrs',data=df)
#This shows a high positive correlation

# %%
sns.swarmplot(x='Rape_Cases_Reported',y='Victims_Between_14-18_Yrs',data=df)
#This also shows a positive correlation

# %%
sns.scatterplot(x='Rape_Cases_Reported',y='Victims_Upto_10_Yrs',data=df)

# %%
df.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %% [markdown]
# Label Encoder usage

# %%
#Converting the categorical data into numeric data using Labelencoder
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

df['Area_Name']=lb.fit_transform(df['Area_Name'])
df['Area_Name']=pd.DataFrame(df['Area_Name'])
df['Area_Name']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 1045    34
# 1046    34
# 1047    34
# 1048    34
# 1049    34
# Name: Area_Name, Length: 1050, dtype: int32

# %%
df['Subgroup']=pd.DataFrame(lb.fit_transform(df['Subgroup']))
df['Subgroup']
# Out:
# 0       0
# 1       1
# 2       2
# 3       0
# 4       1
#        ..
# 1045    1
# 1046    2
# 1047    0
# 1048    1
# 1049    2
# Name: Subgroup, Length: 1050, dtype: int32

# %% [markdown]
# Removing Outliers using zscore

# %%
from scipy.stats import zscore
print(df.shape)
z=np.abs(zscore(df))
df=df[(z<3).all(axis=1)]
df.shape
# Out:
# (1050, 11)
# (963, 11)

# %% [markdown]
# Separating the target and input variable

# %%
#Here we will consider 'Victims_Upto_10_Yrs' as the target variable
x=df.iloc[:,0:-1]
y=pd.DataFrame(df.iloc[:,-1])
print(x.shape)
y.shape
# Out:
# (963, 10)
# (963, 1)

# %% [markdown]
# Checking the skewness of the data

# %%
x.skew()
# Out:
# Area_Name                    0.004005
# Year                         0.040550
# Subgroup                    -0.001863
# Rape_Cases_Reported          1.724181
# Victims_Above_50_Yrs         3.127863
# Victims_Between_10-14_Yrs    2.942592
# Victims_Between_14-18_Yrs    2.747829
# Victims_Between_18-30_Yrs    1.844761
# Victims_Between_30-50_Yrs    2.543817
# Victims_of_Rape_Total        1.723000
# dtype: float64

# %%
#using sqrt function to reduce skewness
for i in x.columns:
    if x.skew()[i]>0.55:
        x[i]=np.sqrt(x[i])

# %%
#checking skewness again
x.skew()
# Out:
# Area_Name                    0.004005
# Year                         0.040550
# Subgroup                    -0.001863
# Rape_Cases_Reported          0.992675
# Victims_Above_50_Yrs         1.847782
# Victims_Between_10-14_Yrs    1.473206
# Victims_Between_14-18_Yrs    1.575908
# Victims_Between_18-30_Yrs    1.058822
# Victims_Between_30-50_Yrs    1.351630
# Victims_of_Rape_Total        0.991742
# dtype: float64

# %%
#as the skewness needs to be reduced again, we use log function to reduce
for i in x.columns:
    if x.skew()[i]>0.55:
        x[i]=np.log1p(x[i])

# %%
x.skew()
#After checking skewness, we know that the skewness has been reduced further
# Out:
# Area_Name                    0.004005
# Year                         0.040550
# Subgroup                    -0.001863
# Rape_Cases_Reported         -0.127587
# Victims_Above_50_Yrs         1.397774
# Victims_Between_10-14_Yrs    0.294333
# Victims_Between_14-18_Yrs    0.263481
# Victims_Between_18-30_Yrs    0.051215
# Victims_Between_30-50_Yrs    0.333463
# Victims_of_Rape_Total       -0.128973
# dtype: float64

# %%
x.head()
# Out:
#    Area_Name  Year  Subgroup  Rape_Cases_Reported  Victims_Above_50_Yrs  \
# 0          0  2001         0             1.005053                   0.0
# 1          0  2001         1             0.693147                   0.0
# 2          0  2001         2             0.881374                   0.0
# 3          0  2002         0             0.881374                   0.0
# 4          0  2002         1             0.000000                   0.0
#
#    Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# 0                        0.0                   1.005053
# 1                        0.0                   0.693147
# 2                        0.0                   0.881374
# 3                        0.0                   0.693147
# 4                        0.0                   0.000000
#
#    Victims_Between_18-30_Yrs  Victims_Between_30-50_Yrs  Victims_of_Rape_Total
# 0                   0.000000                        0.0               1.005053
# ...

# %% [markdown]
# Applying Standardscaler for scaling data

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=scaler.fit_transform(x)
x=pd.DataFrame(x)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.665136 -1.541364 -1.254683 -0.767440 -0.568789 -1.109209 -0.093465
# 1 -1.665136 -1.541364 -0.001302 -1.040263 -0.568789 -1.109209 -0.437260
# 2 -1.665136 -1.541364  1.252080 -0.875622 -0.568789 -1.109209 -0.229789
# 3 -1.665136 -1.193093 -1.254683 -0.875622 -0.568789 -1.109209 -0.437260
# 4 -1.665136 -1.193093 -0.001302 -1.646556 -0.568789 -1.109209 -1.201275
#
#           7         8         9
# 0 -1.359087 -1.061564 -0.768126
# 1 -1.359087 -1.061564 -1.040949
# 2 -1.359087 -1.061564 -0.876307
# 3 -0.764285 -1.061564 -0.876307
# 4 -1.359087 -1.061564 -1.647243

# %% [markdown]
# Calculating best r_state for train_test_split

# %%
#importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
def maxr2_score(regr,x,y):
    max_r2_score=0
    for r_state in range(42,100):
        train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(train_x,train_y)
        pred=regr.predict(test_x)
        r2score=r2_score(test_y,pred)
        print("The r2 score at r state", r_state, "is", r2score )
        if r2score>max_r2_score:
            max_r2_score=r2score
            final_r_state=r_state
    print("The max r2 score", max_r2_score, "is achieved at r_state", final_r_state)

# %%
lr=LinearRegression()
maxr2_score(lr,x,y)
# Out:
# The r2 score at r state 42 is 0.5599242060515328
# The r2 score at r state 43 is 0.5942827791443464
# The r2 score at r state 44 is 0.6164788815482659
# The r2 score at r state 45 is 0.6473256402263263
# The r2 score at r state 46 is 0.5968707850624742
# The r2 score at r state 47 is 0.6069814817956736
# The r2 score at r state 48 is 0.5787089133745109
# The r2 score at r state 49 is 0.5990634675107671
# The r2 score at r state 50 is 0.5796363425491036
# The r2 score at r state 51 is 0.5540925800281877
# The r2 score at r state 52 is 0.5659144202444641
# The r2 score at r state 53 is 0.5768201733448746
# The r2 score at r state 54 is 0.5694750029570294
# The r2 score at r state 55 is 0.5571489526621947
# The r2 score at r state 56 is 0.6002992066612504
# The r2 score at r state 57 is 0.5852790829988352
# The r2 score at r state 58 is 0.6314129012515004
# The r2 score at r state 59 is 0.630257796792925
# The r2 score at r state 60 is 0.58529971052159
# ...

# %%
#Lets finalise the train and test data
train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=77,test_size=0.20)
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (770, 10)
# (770, 1)
# (193, 10)
# (193, 1)

# %%
#Let use Linear Regression and check max r2 score corresponding to different random states
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
r_state=maxr2_score(lr,x,y)
# Out:
# The r2 score at r state 42 is 0.5599242060515328
# The r2 score at r state 43 is 0.5942827791443464
# The r2 score at r state 44 is 0.6164788815482659
# The r2 score at r state 45 is 0.6473256402263263
# The r2 score at r state 46 is 0.5968707850624742
# The r2 score at r state 47 is 0.6069814817956736
# The r2 score at r state 48 is 0.5787089133745109
# The r2 score at r state 49 is 0.5990634675107671
# The r2 score at r state 50 is 0.5796363425491036
# The r2 score at r state 51 is 0.5540925800281877
# The r2 score at r state 52 is 0.5659144202444641
# The r2 score at r state 53 is 0.5768201733448746
# The r2 score at r state 54 is 0.5694750029570294
# The r2 score at r state 55 is 0.5571489526621947
# The r2 score at r state 56 is 0.6002992066612504
# The r2 score at r state 57 is 0.5852790829988352
# The r2 score at r state 58 is 0.6314129012515004
# The r2 score at r state 59 is 0.630257796792925
# The r2 score at r state 60 is 0.58529971052159
# ...

# %%
#Importing necessary libraries
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score

# %%
#Checking gridsearch for different algorithms
sr=SVR()
parameters={'kernel':('linear','rbf'), 'C':[1,10]}
gdsr=GridSearchCV(sr,parameters)
gdsr.fit(train_x,train_y)
gdsr.best_params_

# %%
knn=KNeighborsRegressor()
parameters={'n_neighbors':(1,10)}
gdk=GridSearchCV(knn,parameters)
gdk.fit(train_x,train_y)
gdk.best_params_

# %%
# checking the model and its metrics by running a set of codes.
score=[]
cv=[]
MSE=[]
RMSE=[]
MAE=[]


algorithm=[LinearRegression(),SVR(C= 10, kernel= 'rbf'),DecisionTreeRegressor(),KNeighborsRegressor(n_neighbors=10)]
for i in algorithm:
    l=i
    print(l)
    l.fit(train_x,train_y)
    pred=l.predict(test_x)
    r2score=r2_score(test_y,pred)
    print("R2 score", r2score)
    score.append(r2score)
    crossscore=cross_val_score(l,x,y,cv=5,scoring='r2').mean()
    print("The CV Score is", crossscore)
    cv.append(crossscore)
    mean_sqrd_error=mean_squared_error(test_y,pred)
    MSE.append(mean_sqrd_error)
    print("Mean Squared Error is", mean_sqrd_error )
    rootMSE=np.sqrt(mean_sqrd_error)
    RMSE.append(rootMSE)
    print("Root Mean Squared Error is: ",rootMSE)
    Meanabserror=mean_absolute_error(test_y,pred)
    MAE.append(Meanabserror)
    print("Mean Absolute Error is: ", Meanabserror)
    print("\n")

# %%
result=pd.DataFrame({'Model':['LinearRegression','SVR','DecisionTreeRegressor','KNeighborsRegressor'],'R2score':score,'Cross_val_score':cv,'Mean Squared Error':MSE, 'Root Mean Squared Error': RMSE, 'Mean Absolute Error':MAE})
result

# %%
#Since the models are not giving better scores, we can try Lasso
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_

# %%
#Lets check max r2 score when to use
lsreg=Lasso(alpha=0.01)
r_state=maxr2_score(lsreg,x,y)

# %%
#Lets use cross val score with Lasso
print("Mean r2 score for Lasso Regression:", cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print("standard deviation in r2 score for Lasso Regression: ", cross_val_score(lsreg,x,y,cv=5,scoring='r2').std())
#The lasso here is performing just like Linear Regression

# %%
#Now we will have to use gradient boosting technique
#for getting best parameters we need to use grid search
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 500}

# %%
#Now we will use cross val score to check the mean r2 score and standard deviation
gbr=GradientBoostingRegressor(learning_rate=0.01,n_estimators=500)
print("Mean r2 score for Gradient boosting Regression:", cross_val_score(gbr,x,y,cv=5,scoring='r2').mean())
print("standard deviation in r2 score for Gradient boosting Regression: ", cross_val_score(gbr,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for Gradient boosting Regression: 0.6998112933844733
# standard deviation in r2 score for Gradient boosting Regression:  0.0954438297857871

# %%
# Lets check the maximum r2 score corresponding to this
r_state=maxr2_score(gbr,x,y)
# Out:
# The r2 score at r state 42 is 0.9269741663383774
# The r2 score at r state 43 is 0.8799808493416823
# The r2 score at r state 44 is 0.8980711150438452
# The r2 score at r state 45 is 0.8858672855382765
# The r2 score at r state 46 is 0.8967945611728789
# The r2 score at r state 47 is 0.8895445060020447
# The r2 score at r state 48 is 0.876404955456487
# The r2 score at r state 49 is 0.8819336072620373
# The r2 score at r state 50 is 0.9028135863997371
# The r2 score at r state 51 is 0.9054685629737326
# The r2 score at r state 52 is 0.9005607197808726
# The r2 score at r state 53 is 0.8877249298574538
# The r2 score at r state 54 is 0.8894529067111249
# The r2 score at r state 55 is 0.8929511698377681
# The r2 score at r state 56 is 0.9215271582636042
# The r2 score at r state 57 is 0.8967322402786794
# The r2 score at r state 58 is 0.8903575379635094
# The r2 score at r state 59 is 0.9023433828879243
# The r2 score at r state 60 is 0.8985331256526495
# ...

# %%
#Now we will have to use Adaboost Regression Algorithm 
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lr,lsreg,dt]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 1000}

# %%
#Now we will use cross val score to check the mean r2 score and standard deviation
ada_reg=AdaBoostRegressor(base_estimator= dt,learning_rate=0.001,n_estimators=10)
print("Mean r2 score for Ada boosting Regression:", cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print("standard deviation in r2 score for Ada boosting Regression: ", cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for Ada boosting Regression: 0.5525187017959537
# standard deviation in r2 score for Ada boosting Regression:  0.0958584995920811

# %%
# Lets check the maximum r2 score corresponding to this
r_state=maxr2_score(ada_reg,x,y)
# Out:
# The r2 score at r state 42 is 0.9488018511882097
# The r2 score at r state 43 is 0.93895539550435
# The r2 score at r state 44 is 0.9011439699734085
# The r2 score at r state 45 is 0.9526359913822218
# The r2 score at r state 46 is 0.8800167760064758
# The r2 score at r state 47 is 0.9065100792426957
# The r2 score at r state 48 is 0.8831994904001877
# The r2 score at r state 49 is 0.867009478577009
# The r2 score at r state 50 is 0.9146714961388355
# The r2 score at r state 51 is 0.9425341624585839
# The r2 score at r state 52 is 0.8713353550000337
# The r2 score at r state 53 is 0.8972463864363969
# The r2 score at r state 54 is 0.8537302783800553
# The r2 score at r state 55 is 0.9075708684709256
# The r2 score at r state 56 is 0.9273304194758019
# The r2 score at r state 57 is 0.9184390209273631
# The r2 score at r state 58 is 0.9608141569143496
# The r2 score at r state 59 is 0.860704207151389
# The r2 score at r state 60 is 0.934215063162815
# ...

# %%
#After trying all above let us finalise the model. GradientBoost Regressor is providing the highest accuracy score at 67% and cross validation at 69%
gbr=GradientBoostingRegressor(learning_rate=0.01,n_estimators=500)
gbr.fit(train_x,train_y)
pred=gbr.predict(test_x)
r2score=r2_score(test_y,pred)
print(r2score)
# Out:
# 0.8924482588595825

# %%
#lets save the final model
from sklearn.externals import joblib

#save the model as pickle in a file
joblib.dump(gbr,'Crime.pkl')
# Out:
# ['Crime.pkl']
