# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the dataset
df =pd.read_csv('Happiness score.csv')

# %%
#print the top dataset
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
#to find the number of rows and columns
df.shape
# Out:
# (158, 12)

# %%
#to describe the data
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
col_names=['country','happiness_rank','happiness_score','family','gdp','life_expectancy','freedom','govt_corruption','generosity']

# %%
#to see the column names
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df=df[['Country', 'Happiness Rank', 'Happiness Score','Family','Economy (GDP per Capita)','Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)','Generosity' ]]

# %%
df.head()
# Out:
#        Country  Happiness Rank  Happiness Score   Family  \
# 0  Switzerland               1            7.587  1.34951
# 1      Iceland               2            7.561  1.40223
# 2      Denmark               3            7.527  1.36058
# 3       Norway               4            7.522  1.33095
# 4       Canada               5            7.427  1.32261
#
#    Economy (GDP per Capita)  Health (Life Expectancy)  Freedom  \
# 0                   1.39651                   0.94143  0.66557
# 1                   1.30232                   0.94784  0.62877
# 2                   1.32548                   0.87464  0.64938
# 3                   1.45900                   0.88521  0.66973
# 4                   1.32629                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity
# 0                        0.41978     0.29678
# 1                        0.14145     0.43630
# 2                        0.48357     0.34139
# 3                        0.36503     0.34699
# ...

# %%
df.columns=col_names

# %%
df.head()
# Out:
#        country  happiness_rank  happiness_score   family      gdp  \
# 0  Switzerland               1            7.587  1.34951  1.39651
# 1      Iceland               2            7.561  1.40223  1.30232
# 2      Denmark               3            7.527  1.36058  1.32548
# 3       Norway               4            7.522  1.33095  1.45900
# 4       Canada               5            7.427  1.32261  1.32629
#
#    life_expectancy  freedom  govt_corruption  generosity
# 0          0.94143  0.66557          0.41978     0.29678
# 1          0.94784  0.62877          0.14145     0.43630
# 2          0.87464  0.64938          0.48357     0.34139
# 3          0.88521  0.66973          0.36503     0.34699
# 4          0.90563  0.63297          0.32957     0.45811

# %%
#to see the number of columns and rows after removing the unwanted ones
df.shape
# Out:
# (158, 9)

# %%
#to check if any column contains any null value
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
#to check the presence of any null value
df.isnull().sum()
# Out:
# country            0
# happiness_rank     0
# happiness_score    0
# family             0
# gdp                0
# life_expectancy    0
# freedom            0
# govt_corruption    0
# generosity         0
# dtype: int64

# %%
#to know the data types of the columns
df.dtypes
# Out:
# country             object
# happiness_rank       int64
# happiness_score    float64
# family             float64
# gdp                float64
# life_expectancy    float64
# freedom            float64
# govt_corruption    float64
# generosity         float64
# dtype: object

# %% [markdown]
# Relationship between the Happiness Score and the other variables

# %%
df.plot(kind='scatter', x='family', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,1))
plt.xlabel('Family')
plt.ylabel('Happiness Score')
plt.title('Happiness score -Family')
# Out:
# Text(0.5, 1.0, 'Happiness score -Family')

# %%
df.plot(kind='scatter', x='gdp', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,2))
plt.xlabel('GDP')
plt.ylabel('Happiness Score')
plt.title('Happiness score -Economy')
# Out:
# Text(0.5, 1.0, 'Happiness score -Economy')

# %%
df.plot(kind='scatter', x='life_expectancy', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,3))
plt.xlabel('Life Expectancy')
plt.ylabel('Happiness Score')
plt.title('Happiness score -Life Expectancy')
# Out:
# Text(0.5, 1.0, 'Happiness score -Life Expectancy')

# %%
df.plot(kind='scatter', x='freedom', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,4))
plt.xlabel('Freedom')
plt.ylabel('Happiness Score')
plt.title('Happiness score -Freedom')
# Out:
# Text(0.5, 1.0, 'Happiness score -Freedom')

# %%
df.plot(kind='scatter', x='govt_corruption', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,5))
plt.xlabel('Govt Corruption')
plt.ylabel('Happiness Score')
plt.title('Happiness score - Govt Corruption')
# Out:
# Text(0.5, 1.0, 'Happiness score - Govt Corruption')

# %%
df.plot(kind='scatter', x='generosity', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,6))
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.title('Happiness Score- Generosity')
# Out:
# Text(0.5, 1.0, 'Happiness Score- Generosity')

# %%
df_test=df[['happiness_score']]
df_test
# Out:
#      happiness_score
# 0              7.587
# 1              7.561
# 2              7.527
# 3              7.522
# 4              7.427
# ..               ...
# 153            3.465
# 154            3.340
# 155            3.006
# 156            2.905
# 157            2.839
#
# [158 rows x 1 columns]

# %%
corr=df.corr()
corr
# Out:
#                  happiness_rank  happiness_score    family       gdp  \
# happiness_rank         1.000000        -0.992105 -0.733644 -0.785267
# happiness_score       -0.992105         1.000000  0.740605  0.780966
# family                -0.733644         0.740605  1.000000  0.645299
# gdp                   -0.785267         0.780966  0.645299  1.000000
# life_expectancy       -0.735613         0.724200  0.531104  0.816478
# freedom               -0.556886         0.568211  0.441518  0.370300
# govt_corruption       -0.372315         0.395199  0.205605  0.307885
# generosity            -0.160142         0.180319  0.087513 -0.010465
#
#                  life_expectancy   freedom  govt_corruption  generosity
# happiness_rank         -0.735613 -0.556886        -0.372315   -0.160142
# happiness_score         0.724200  0.568211         0.395199    0.180319
# family                  0.531104  0.441518         0.205605    0.087513
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr,cmap='Blues',annot=True)
plt.title('Correlation in 2015',fontsize=25)
# Out:
# Text(0.5, 1, 'Correlation in 2015')

# %%
fig=plt.figure(figsize=(15, 10))

ax1 = fig.add_subplot(321)
sns.regplot(x='family',y='happiness_score',data=df, ax=ax1)

ax2 = fig.add_subplot(322)
sns.regplot(x='gdp', y='happiness_score',data=df, ax=ax2)

ax3 = fig.add_subplot(323)
sns.regplot(x='life_expectancy', y='happiness_score',data=df, ax=ax3)

ax4 = fig.add_subplot(324)
sns.regplot(x='freedom', y='happiness_score',data=df, ax=ax4)

ax5 = fig.add_subplot(325)
sns.regplot(x='govt_corruption', y='happiness_score',data=df, ax=ax5)

ax6 = fig.add_subplot(326)
sns.regplot(x='generosity', y='happiness_score',data=df, ax=ax6)

# %% [markdown]
# Pearson Correlation:
# The Pearson Correlation measures the linear dependence between two variables X and Y.
#
# The resulting coefficient is a value between -1 and 1 inclusive, where:
#
# 1: Total positive linear correlation.
# 0: No linear correlation, the two variables most likely do not affect each other.
# -1: Total negative linear correlation.
# Pearson Correlation is the default method of the function "corr". Like before we can calculate the Pearson Correlation of the of the 'int64' or 'float64' variables.
#
# P-value:
# What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.
#
# By convention, when the
#
# p-value is $&lt;$ 0.001: we say there is strong evidence that the correlation is significant.
# the p-value is $&lt;$ 0.05: there is moderate evidence that the correlation is significant.
# the p-value is $&lt;$ 0.1: there is weak evidence that the correlation is significant.
# the p-value is $&gt;$ 0.1: there is no evidence that the correlation is significant.

# %%
from scipy import stats

# %% [markdown]
# Family vs Happiness score

# %%
pearson_coef,p_value=stats.pearsonr(df['family'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.7406051972367846 9.918850000100599e-29

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001,
# the correlation between family and happiness score is statistically significant, and the linear relationship is moderately strong (~0.740).

# %% [markdown]
# Gdp vs Happiness Score

# %%
pearson_coef,p_value=stats.pearsonr(df['gdp'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.7809655268660214 1.050538413195903e-33

# %% [markdown]
# Conclusion: Since the p value is <0.001, the correlation between gdp and happiness score is statistically significant, and the linear relationship is quite strong (~0.780)

# %% [markdown]
# Life Expectancy vs Happiness score

# %%
pearson_coef,p_value=stats.pearsonr(df['life_expectancy'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.7241995951050699 5.7888955059006694e-27

# %% [markdown]
# Conclusion : Since the p value is <0.001, the correlation between the life expectancy and happiness score is statistically significant and the linear relationship is strong ~0.724

# %% [markdown]
# Freedom vs Happiness score

# %%
pearson_coef,p_value=stats.pearsonr(df['freedom'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.5682109041925174 6.8758081608472496e-15

# %% [markdown]
# Since the p-value is < 0.001, the correlation between freedom and happiness score is statistically significant, and the linear relationship is moderately strong (~0.5682).

# %% [markdown]
# Govt curruption vs Happiness score

# %%
pearson_coef,p_value=stats.pearsonr(df['govt_corruption'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.3951985838369112 2.763802425204147e-07

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001, the correlation between govt corrpution and happiness score is statistically significant, and the linear relationship is positive strong (~0.4).

# %% [markdown]
# Generosity vs Happiness score

# %%
pearson_coef,p_value=stats.pearsonr(df['generosity'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.18031852669717452 0.023378715912796996

# %% [markdown]
# Conclusion:
# Since the p-value is < 0.001, the correlation between generosity and happiness score is statistically significant, and the linear relationship is weak. (~0.1803).

# %% [markdown]
# Models

# %%
data=df.groupby('country')['happiness_score','family','gdp','life_expectancy','freedom','govt_corruption'].mean().reset_index()

x=df[['family','gdp','life_expectancy','freedom','govt_corruption']]
y=df['happiness_score']
# Out:
# C:\Users\softech\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=50)
x_train.head()
# Out:
#       family      gdp  life_expectancy  freedom  govt_corruption
# 151  0.85188  0.25812          0.27125  0.39493          0.12832
# 104  0.95348  0.59532          0.69510  0.40148          0.06825
# 72   1.22791  1.15174          0.77361  0.44888          0.15184
# 84   0.91612  0.47038          0.29924  0.48827          0.12468
# 38   1.16594  1.55422          0.72492  0.55499          0.25609

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
LR=LinearRegression()
LA=Lasso()
RI=Ridge()
EN=ElasticNet()
KNR=KNeighborsRegressor()
DTR=DecisionTreeRegressor(random_state=63)
ABR=AdaBoostRegressor(random_state=63)
RFR=RandomForestRegressor(random_state=63)
GBR=GradientBoostingRegressor(random_state=63)
XGR=XGBRegressor(random_state=63)

# %%
models=[]
models.append(('LinearRegression',LR))
models.append(('Lasso',LA))
models.append(('Ridge',RI))
models.append(('ElasticNet',EN))
models.append(('DecisionTreeRegressor',DTR))
models.append(('KNeighborsRegressor',KNR))
models.append(('AdaBoostRegressor',ABR))
models.append(('RandomForestRegressor',RFR))
models.append(('GradientBoostingRegressor',GBR))
models.append(('XGBRegressor',XGR))

# %%
from sklearn.metrics import r2_score,mean_squared_error

Model=[]
R2_score=[]
cvs=[]
MSE=[]
for name,model in models:
    print('*********************************',name,'*********************************')
    print('\n',model)
    Model.append(name)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    r2=r2_score(y_test,pre)
    print('R2_score = ',r2)
    R2_score.append(r2)
    mse=mean_squared_error(y_test,pre)
    print("Mean_Squared_Error =",mse)
    MSE.append(round(mse,3))
    score= cross_val_score(model,x,y,cv=10,scoring='r2').mean()
    print('Cross_Val_Score = ',score)
    cvs.append(round(score,3))
    print('\n')
# Out:
# ********************************* LinearRegression *********************************
#
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# R2_score =  0.8080859895650161
# Mean_Squared_Error = 0.2569635573905861
# Cross_Val_Score =  -24.994516963298327
#
#
# ********************************* Lasso *********************************
#
#  Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
# R2_score =  -0.05705803801397247
# Mean_Squared_Error = 1.4153494744897963
# Cross_Val_Score =  -67.88244292260013
#
#
# ********************************* Ridge *********************************
#
#  Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)
# R2_score =  0.7997167293111994
# Mean_Squared_Error = 0.26816959119017125
# ...

# %%
result = pd.DataFrame({'Model': Model, 'R2_score': R2_score ,'Mean_Squared_Error' :MSE,'Cross_val_score':cvs})
result
# Out:
#                        Model  R2_score  Mean_Squared_Error  Cross_val_score
# 0           LinearRegression  0.808086               0.257          -24.995
# 1                      Lasso -0.057058               1.415          -67.882
# 2                      Ridge  0.799717               0.268          -24.576
# 3                 ElasticNet -0.057058               1.415          -67.882
# 4      DecisionTreeRegressor  0.534303               0.624          -52.882
# 5        KNeighborsRegressor  0.795489               0.274          -31.275
# 6          AdaBoostRegressor  0.796654               0.272          -30.246
# 7      RandomForestRegressor  0.713303               0.384          -28.971
# 8  GradientBoostingRegressor  0.672595               0.438          -34.130
# 9               XGBRegressor  0.669507               0.443          -32.157

# %%
#Conclusion: We came up with that that from Linear Regression we get highest value of r^2 and lowest mean square value

#Distribution plot for Visualization of of our predicted value and actual value

# %%
#Distribution plot for Visualization of of our predicted value and actual value

def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, t1_train, "Actual Values (Train)", "Predicted Values (Train)", Title)

# %%
Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test,t1_test,"Actual Values (Test)","Predicted Values (Test)",Title)

# %%
#Conclusion This is very helpful because you will get know that the factors important for happiness of a nation. Here we can see that the happiness is highly correlated to GDP and Healthy Life expectancy and, a strong correlation with people social support and Freedom. Also generoisity and corruption is the least correlated to Happiness.

# %%
#lets save the final model
from sklearn.externals import joblib

#save the model as pickle in a file
joblib.dump(lm1,'happiness.pkl')
# Out:
# ['happiness.pkl']
